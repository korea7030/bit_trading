# %%
import pandas as pd
import pyupbit

# %%
import time

# %%
df2 = pyupbit.get_ohlcv('KRW-BTC', 'minute5', to='20220224 00:00:00', count=288)

# %%
df2 = pyupbit.get_ohlcv('KRW-BTC', 'minute5', to='20220224 00:00:00', count=8928)

# %%
# df2.head()

# %%
df2_reset = df2.reset_index()
df2_reset.columns = ['timestamp', 'open', 'high', 'low', 'close', 'volume', 'value']

# %%
# df = pd.read_csv('./data/data.csv')

# %%
# df.head()

# %%
df2_reset.head()
# Out:
#             timestamp        open        high         low       close  \
# 0 2022-02-23 00:00:00  46484000.0  46484000.0  46227000.0  46382000.0
# 1 2022-02-23 00:05:00  46382000.0  46423000.0  46221000.0  46336000.0
# 2 2022-02-23 00:10:00  46337000.0  46392000.0  46264000.0  46390000.0
# 3 2022-02-23 00:15:00  46390000.0  46403000.0  46310000.0  46389000.0
# 4 2022-02-23 00:20:00  46389000.0  46588000.0  46342000.0  46342000.0
#
#       volume         value
# 0  30.779414  1.427016e+09
# 1  25.983686  1.203394e+09
# 2  12.084786  5.599988e+08
# 3  20.966600  9.723824e+08
# 4  28.698938  1.332195e+09

# %%
from upbit_backtest import backtesting

# %%
backtesting(df2_reset)
# Out:
# ======================= 음봉전환 stick_size :: 102000.0 ================
# ==============2022-02-23 00:00:00 음봉전환 ================
# ==============2022-02-23 00:00:00 이전 5분봉 크기 : -147000.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46826000.0 ######################################################
# ======================= 음봉전환 stick_size :: 46000.0 ================
# ==============2022-02-23 00:05:00 음봉전환 ================
# ==============2022-02-23 00:05:00 이전 5분봉 크기 : -106000.0 ============
# ###################################################### tic_count : 2, tic : 1, tic_start: 46382000.0 ######################################################
# ======================= 양봉전환 stick_size :: -53000.0 ================
# ======================= 음봉전환 stick_size :: 1000.0 ================
# ==============2022-02-23 00:15:00 음봉전환 ================
# ==============2022-02-23 00:15:00 이전 5분봉 크기 : -50200.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46390000.0 ######################################################
# ======================= 음봉전환 stick_size :: 47000.0 ================
# ==============2022-02-23 00:20:00 음봉전환 ================
# ==============2022-02-23 00:20:00 이전 5분봉 크기 : 18200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 47000.0, 이전5봉 : 18200.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 46389000.0 ######################################################
# ======================= 양봉전환 stick_size :: -147000.0 ================
# ======================= 음봉전환 stick_size :: 47000.0 ================
# ==============2022-02-23 00:30:00 음봉전환 ================
# ==============2022-02-23 00:30:00 이전 5분봉 크기 : -21200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 47000.0, 이전5봉 : 21200.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46506000.0 ######################################################
# ======================= 음봉전환 stick_size :: 101000.0 ================
# ==============2022-02-23 00:35:00 음봉전환 ================
# ==============2022-02-23 00:35:00 이전 5분봉 크기 : -21000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 101000.0, 이전5봉 : 21000.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 46411000.0 ######################################################
# ======================= 음봉전환 stick_size :: 107000.0 ================
# ==============2022-02-23 00:40:00 음봉전환 ================
# ==============2022-02-23 00:40:00 이전 5분봉 크기 : 9800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 107000.0, 이전5봉 : 9800.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ==================== 구매 tic : 3 ===============
# Buy KRW-BTC, KRW: 10163.34
# ======================== 2022-02-23 00:40:00 시간 매수 완료 : 46197000.0 ===============
# ============================= 2022-02-23 00:40:00 시간 가격 : 46197000.0, 매수평균 금액 : 46197000.0 ===============
# ###################################################### tic_count : 0, tic : 0, tic_start: 0 ######################################################
# ======================= 양봉전환 stick_size :: -40000.0 ================
# ============== 수익률 9.048206593502373e-06 =================
# ======================= 음봉전환 stick_size :: 61000.0 ================
# ==============2022-02-23 00:50:00 음봉전환 ================
# ==============2022-02-23 00:50:00 이전 5분봉 크기 : 13600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 61000.0, 이전5봉 : 13600.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46216000.0 ######################################################
# ======================= 음봉전환 stick_size :: 55000.0 ================
# ==============2022-02-23 00:55:00 음봉전환 ================
# ==============2022-02-23 00:55:00 이전 5분봉 크기 : 55200.0 ============
# ###################################################### tic_count : 2, tic : 2, tic_start: 46156000.0 ######################################################
# ======================= 양봉전환 stick_size :: -167000.0 ================
# ============== 수익률 -1.3334199190423306e-05 =================
# ======================= 음봉전환 stick_size :: 286000.0 ================
# ==============2022-02-23 01:05:00 음봉전환 ================
# ==============2022-02-23 01:05:00 이전 5분봉 크기 : 3200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 286000.0, 이전5봉 : 3200.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46169000.0 ######################################################
# ======================= 음봉전환 stick_size :: 33000.0 ================
# ==============2022-02-23 01:10:00 음봉전환 ================
# ==============2022-02-23 01:10:00 이전 5분봉 크기 : 39000.0 ============
# ###################################################### tic_count : 2, tic : 1, tic_start: 45853000.0 ######################################################
# ======================= 음봉전환 stick_size :: 64000.0 ================
# ==============2022-02-23 01:15:00 음봉전환 ================
# ==============2022-02-23 01:15:00 이전 5분봉 크기 : 53600.0 ============
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 2, tic_start: 45794000.0 ######################################################
# ======================= 양봉전환 stick_size :: -123000.0 ================
# ============== 수익률 -0.000133341991904237 =================
# ======================= 음봉전환 stick_size :: 57000.0 ================
# ==============2022-02-23 01:25:00 음봉전환 ================
# ==============2022-02-23 01:25:00 이전 5분봉 크기 : 18600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 57000.0, 이전5봉 : 18600.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 45917000.0 ######################################################
# ======================= 음봉전환 stick_size :: 10000.0 ================
# ==============2022-02-23 01:30:00 음봉전환 ================
# ==============2022-02-23 01:30:00 이전 5분봉 크기 : 63400.0 ============
# ###################################################### tic_count : 2, tic : 1, tic_start: 45861000.0 ######################################################
# ======================= 음봉전환 stick_size :: 86000.0 ================
# ==============2022-02-23 01:35:00 음봉전환 ================
# ==============2022-02-23 01:35:00 이전 5분봉 크기 : 8200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 86000.0, 이전5봉 : 8200.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 2, tic_start: 45760000.0 ######################################################
# ======================= 양봉전환 stick_size :: -45000.0 ================
# ============== 수익률 -0.0001595341688854231 =================
# ======================= 양봉전환 stick_size :: -29000.0 ================
# ============== 수익률 -0.00014572374829534322 =================
# ======================= 음봉전환 stick_size :: 51000.0 ================
# ==============2022-02-23 01:50:00 음봉전환 ================
# ==============2022-02-23 01:50:00 이전 5분봉 크기 : 15800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 51000.0, 이전5봉 : 15800.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 45891000.0 ######################################################
# ======================= 양봉전환 stick_size :: -14000.0 ================
# ============== 수익률 -0.00015858172608610997 =================
# ======================= 양봉전환 stick_size :: -28000.0 ================
# ============== 수익률 -0.00012286512111176097 =================
# ======================= 음봉전환 stick_size :: 50000.0 ================
# ==============2022-02-23 02:05:00 음봉전환 ================
# ==============2022-02-23 02:05:00 이전 5분봉 크기 : -13000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 50000.0, 이전5봉 : 13000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 45939000.0 ######################################################
# ======================= 음봉전환 stick_size :: 179000.0 ================
# ==============2022-02-23 02:10:00 음봉전환 ================
# ==============2022-02-23 02:10:00 이전 5분봉 크기 : 6000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 179000.0, 이전5봉 : 6000.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 45889000.0 ######################################################
# ======================= 음봉전환 stick_size :: 143000.0 ================
# ==============2022-02-23 02:15:00 음봉전환 ================
# ==============2022-02-23 02:15:00 이전 5분봉 크기 : 47600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 143000.0, 이전5봉 : 47600.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ==================== 구매 tic : 3 ===============
# Buy KRW-BTC, KRW: 10046.08
# ======================== 2022-02-23 02:15:00 시간 매수 완료 : 45664000.0 ===============
# ============================= 2022-02-23 02:15:00 시간 가격 : 45664000.0, 매수평균 금액 : 45930499.99999999 ===============
# ###################################################### tic_count : 0, tic : 0, tic_start: 0 ######################################################
# ======================= 양봉전환 stick_size :: -34000.0 ================
# ============== 수익률 -0.00021219015686743916 =================
# ======================= 양봉전환 stick_size :: -30000.0 ================
# ============== 수익률 -0.0001757873308585754 =================
# ======================= 양봉전환 stick_size :: -79000.0 ================
# ============== 수익률 -0.00015758591785414354 =================
# ======================= 양봉전환 stick_size :: -103000.0 ================
# ============== 수익률 -6.753682193748556e-05 =================
# ======================= 음봉전환 stick_size :: 27000.0 ================
# ==============2022-02-23 02:40:00 음봉전환 ================
# ==============2022-02-23 02:40:00 이전 5분봉 크기 : -20600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 45860000.0 ######################################################
# ======================= 음봉전환 stick_size :: 41000.0 ================
# ==============2022-02-23 02:45:00 음봉전환 ================
# ==============2022-02-23 02:45:00 이전 5분봉 크기 : -43800.0 ============
# ###################################################### tic_count : 2, tic : 1, tic_start: 45783000.0 ######################################################
# ======================= 양봉전환 stick_size :: -117000.0 ================
# ============== 수익률 -6.849479104298697e-05 =================
# ======================= 음봉전환 stick_size :: 13000.0 ================
# ==============2022-02-23 02:55:00 음봉전환 ================
# ==============2022-02-23 02:55:00 이전 5분봉 크기 : -46200.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 45859000.0 ######################################################
# ======================= 양봉전환 stick_size :: -33000.0 ================
# ============== 수익률 -1.2932582924197845e-05 =================
# ======================= 양봉전환 stick_size :: -55000.0 ================
# ============== 수익률 2.2512273979172412e-05 =================
# ======================= 음봉전환 stick_size :: 37000.0 ================
# ==============2022-02-23 03:10:00 음봉전환 ================
# ==============2022-02-23 03:10:00 이전 5분봉 크기 : -30200.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 45954000.0 ######################################################
# ======================= 음봉전환 stick_size :: 73000.0 ================
# ==============2022-02-23 03:15:00 음봉전환 ================
# ==============2022-02-23 03:15:00 이전 5분봉 크기 : -31000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 73000.0, 이전5봉 : 31000.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 45917000.0 ######################################################
# ======================= 음봉전환 stick_size :: 49000.0 ================
# ==============2022-02-23 03:20:00 음봉전환 ================
# ==============2022-02-23 03:20:00 이전 5분봉 크기 : 7000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 49000.0, 이전5봉 : 7000.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 2, tic_start: 45852000.0 ######################################################
# ======================= 음봉전환 stick_size :: 80000.0 ================
# ==============2022-02-23 03:25:00 음봉전환 ================
# ==============2022-02-23 03:25:00 이전 5분봉 크기 : 14200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 80000.0, 이전5봉 : 14200.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ==================== 구매 tic : 3 ===============
# Buy KRW-BTC, KRW: 10076.0
# ======================== 2022-02-23 03:25:00 시간 매수 완료 : 45800000.0 ===============
# ============================= 2022-02-23 03:25:00 시간 가격 : 45800000.0, 매수평균 금액 : 45887000.0 ===============
# ###################################################### tic_count : 0, tic : 0, tic_start: 0 ######################################################
# ======================= 양봉전환 stick_size :: -167000.0 ================
# ============== 수익률 0.00011362695316757045 =================
# ======================= 양봉전환 stick_size :: -20000.0 ================
# ============== 수익률 0.0001222568483448519 =================
# ======================= 양봉전환 stick_size :: -102000.0 ================
# ============== 수익률 0.0002459520125525761 =================
# ======================= 음봉전환 stick_size :: 97000.0 ================
# ==============2022-02-23 03:45:00 음봉전환 ================
# ==============2022-02-23 03:45:00 이전 5분봉 크기 : -32000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 97000.0, 이전5봉 : 32000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46058000.0 ######################################################
# ======================= 음봉전환 stick_size :: 124000.0 ================
# ==============2022-02-23 03:50:00 음봉전환 ================
# ==============2022-02-23 03:50:00 이전 5분봉 크기 : -22400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 124000.0, 이전5봉 : 22400.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 45977000.0 ######################################################
# ======================= 음봉전환 stick_size :: 31000.0 ================
# ==============2022-02-23 03:55:00 음봉전환 ================
# ==============2022-02-23 03:55:00 이전 5분봉 크기 : -13600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 31000.0, 이전5봉 : 13600.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ==================== 구매 tic : 3 ===============
# Buy KRW-BTC, KRW: 10091.62
# ======================== 2022-02-23 03:55:00 시간 매수 완료 : 45871000.0 ===============
# ============================= 2022-02-23 03:55:00 시간 가격 : 45871000.0, 매수평균 금액 : 45883000.0 ===============
# ###################################################### tic_count : 0, tic : 0, tic_start: 0 ######################################################
# ======================= 양봉전환 stick_size :: -25000.0 ================
# ============== 수익률 2.4932981714365512e-05 =================
# ======================= 양봉전환 stick_size :: -43000.0 ================
# ============== 수익률 3.06867467253705e-05 =================
# ======================= 양봉전환 stick_size :: -140000.0 ================
# ============== 수익률 0.00029919578057232275 =================
# ======================= 음봉전환 stick_size :: 2000.0 ================
# ==============2022-02-23 04:15:00 음봉전환 ================
# ==============2022-02-23 04:15:00 이전 5분봉 크기 : -10600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46039000.0 ######################################################
# ======================= 음봉전환 stick_size :: 120000.0 ================
# ==============2022-02-23 04:20:00 음봉전환 ================
# ==============2022-02-23 04:20:00 이전 5분봉 크기 : -35000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 120000.0, 이전5봉 : 35000.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 46036000.0 ######################################################
# ======================= 양봉전환 stick_size :: -168000.0 ================
# ============== 수익률 0.00045838327921016435 =================
# ======================= 양봉전환 stick_size :: -187000.0 ================
# ============== 수익률 0.0007038772530130966 =================
# ======================= 음봉전환 stick_size :: 17000.0 ================
# ==============2022-02-23 04:35:00 음봉전환 ================
# ==============2022-02-23 04:35:00 이전 5분봉 크기 : -74600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46250000.0 ######################################################
# ======================= 음봉전환 stick_size :: 102000.0 ================
# ==============2022-02-23 04:40:00 음봉전환 ================
# ==============2022-02-23 04:40:00 이전 5분봉 크기 : -43200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 102000.0, 이전5봉 : 43200.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 46232000.0 ######################################################
# ======================= 양봉전환 stick_size :: -164000.0 ================
# ============== 수익률 0.0007825120414968526 =================
# ======================= 음봉전환 stick_size :: 26000.0 ================
# ==============2022-02-23 04:50:00 음봉전환 ================
# ==============2022-02-23 04:50:00 이전 5분봉 크기 : -80000.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46291000.0 ######################################################
# ======================= 양봉전환 stick_size :: -46000.0 ================
# ============== 수익률 0.0008227883965739034 =================
# ======================= 양봉전환 stick_size :: -163000.0 ================
# ============== 수익률 0.0011833576705969511 =================
# ======================= 음봉전환 stick_size :: 144000.0 ================
# ==============2022-02-23 05:05:00 음봉전환 ================
# ==============2022-02-23 05:05:00 이전 5분봉 크기 : -49000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 144000.0, 이전5봉 : 49000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46500000.0 ######################################################
# ======================= 양봉전환 stick_size :: -16000.0 ================
# ============== 수익률 0.0009244382451016793 =================
# ======================= 음봉전환 stick_size :: 126000.0 ================
# ==============2022-02-23 05:15:00 음봉전환 ================
# ==============2022-02-23 05:15:00 이전 5분봉 크기 : -11000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 126000.0, 이전5봉 : 11000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46365000.0 ######################################################
# ======================= 음봉전환 stick_size :: 38000.0 ================
# ==============2022-02-23 05:20:00 음봉전환 ================
# ==============2022-02-23 05:20:00 이전 5분봉 크기 : 9000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 38000.0, 이전5봉 : 9000.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 46239000.0 ######################################################
# ======================= 양봉전환 stick_size :: -108000.0 ================
# ============== 수익률 0.0008189525532332281 =================
# ======================= 양봉전환 stick_size :: -3000.0 ================
# ============== 수익률 0.0007326460780681374 =================
# ======================= 양봉전환 stick_size :: -73000.0 ================
# ============== 수익률 0.0008074450232112181 =================
# ======================= 음봉전환 stick_size :: 130000.0 ================
# ==============2022-02-23 05:40:00 음봉전환 ================
# ==============2022-02-23 05:40:00 이전 5분봉 크기 : -4000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 130000.0, 이전5봉 : 4000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46304000.0 ######################################################
# ======================= 음봉전환 stick_size :: 42000.0 ================
# ==============2022-02-23 05:45:00 음봉전환 ================
# ==============2022-02-23 05:45:00 이전 5분봉 크기 : -3200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 42000.0, 이전5봉 : 3200.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 46177000.0 ######################################################
# ======================= 양봉전환 stick_size :: -54000.0 ================
# ============== 수익률 0.0005523614410566055 =================
# ======================= 양봉전환 stick_size :: -22000.0 ================
# ============== 수익률 0.0006214066211886812 =================
# ======================= 양봉전환 stick_size :: -64000.0 ================
# ============== 수익률 0.0008323780049255677 =================
# ======================= 양봉전환 stick_size :: -17000.0 ================
# ============== 수익률 0.0008649826733212679 =================
# ======================= 음봉전환 stick_size :: 18000.0 ================
# ==============2022-02-23 06:10:00 음봉전환 ================
# ==============2022-02-23 06:10:00 이전 5분봉 크기 : -23000.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46334000.0 ######################################################
# ======================= 음봉전환 stick_size :: 52000.0 ================
# ==============2022-02-23 06:15:00 음봉전환 ================
# ==============2022-02-23 06:15:00 이전 5분봉 크기 : -27800.0 ============
# ###################################################### tic_count : 2, tic : 1, tic_start: 46258000.0 ######################################################
# ======================= 양봉전환 stick_size :: -53000.0 ================
# ============== 수익률 0.0007345639997384672 =================
# ======================= 양봉전환 stick_size :: -29000.0 ================
# ============== 수익률 0.0007959374931891923 =================
# ======================= 음봉전환 stick_size :: 60000.0 ================
# ==============2022-02-23 06:30:00 음봉전환 ================
# ==============2022-02-23 06:30:00 이전 5분봉 크기 : -5800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 60000.0, 이전5봉 : 5800.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46298000.0 ######################################################
# ======================= 음봉전환 stick_size :: 51000.0 ================
# ==============2022-02-23 06:35:00 음봉전환 ================
# ==============2022-02-23 06:35:00 이전 5분봉 크기 : 9600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 51000.0, 이전5봉 : 9600.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 46238000.0 ######################################################
# ======================= 양봉전환 stick_size :: -94000.0 ================
# ============== 수익률 0.0007614149031231624 =================
# ======================= 음봉전환 stick_size :: 11000.0 ================
# ==============2022-02-23 06:45:00 음봉전환 ================
# ==============2022-02-23 06:45:00 이전 5분봉 크기 : -13000.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46280000.0 ######################################################
# ======================= 음봉전환 stick_size :: 39000.0 ================
# ==============2022-02-23 06:50:00 음봉전환 ================
# ==============2022-02-23 06:50:00 이전 5분봉 크기 : -200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 39000.0, 이전5봉 : 200.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 46264000.0 ######################################################
# ======================= 음봉전환 stick_size :: 85000.0 ================
# ==============2022-02-23 06:55:00 음봉전환 ================
# ==============2022-02-23 06:55:00 이전 5분봉 크기 : 13400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 85000.0, 이전5봉 : 13400.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 2, tic_start: 46140000.0 ######################################################
# ======================= 양봉전환 stick_size :: -54000.0 ================
# ============== 수익률 0.0005964736394743158 =================
# ======================= 양봉전환 stick_size :: -17000.0 ================
# ============== 수익률 0.0006329141512106913 =================
# ======================= 음봉전환 stick_size :: 17000.0 ================
# ==============2022-02-23 07:10:00 음봉전환 ================
# ==============2022-02-23 07:10:00 이전 5분봉 크기 : 12800.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46213000.0 ######################################################
# ======================= 음봉전환 stick_size :: 48000.0 ================
# ==============2022-02-23 07:15:00 음봉전환 ================
# ==============2022-02-23 07:15:00 이전 5분봉 크기 : 14000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 48000.0, 이전5봉 : 14000.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 46220000.0 ######################################################
# ======================= 양봉전환 stick_size :: -9000.0 ================
# ============== 수익률 0.0005734585794302958 =================
# ======================= 음봉전환 stick_size :: 47000.0 ================
# ==============2022-02-23 07:25:00 음봉전환 ================
# ==============2022-02-23 07:25:00 이전 5분봉 크기 : -3000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 47000.0, 이전5봉 : 3000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46182000.0 ######################################################
# ======================= 음봉전환 stick_size :: 92000.0 ================
# ==============2022-02-23 07:30:00 음봉전환 ================
# ==============2022-02-23 07:30:00 이전 5분봉 크기 : 17200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 92000.0, 이전5봉 : 17200.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 46082000.0 ######################################################
# ======================= 양봉전환 stick_size :: -10000.0 ================
# ============== 수익률 0.00022439683542924203 =================
# ======================= 양봉전환 stick_size :: -51000.0 ================
# ============== 수익률 0.00032221084061635855 =================
# ======================= 양봉전환 stick_size :: -70000.0 ================
# ============== 수익률 0.000521674694331235 =================
# ======================= 음봉전환 stick_size :: 99000.0 ================
# ==============2022-02-23 07:50:00 음봉전환 ================
# ==============2022-02-23 07:50:00 이전 5분봉 크기 : 1600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 99000.0, 이전5봉 : 1600.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46155000.0 ######################################################
# ======================= 양봉전환 stick_size :: -13000.0 ================
# ============== 수익률 0.0004104352374517789 =================
# ======================= 양봉전환 stick_size :: -3000.0 ================
# ============== 수익률 0.00041618900246278385 =================
# ======================= 양봉전환 stick_size :: -64000.0 ================
# ============== 수익률 0.0005293463810125698 =================
# ======================= 양봉전환 stick_size :: -61000.0 ================
# ============== 수익률 0.0006463396029030309 =================
# ======================= 양봉전환 stick_size :: -20000.0 ================
# ============== 수익률 0.0006846980363097519 =================
# ======================= 양봉전환 stick_size :: -18000.0 ================
# ============== 수익률 0.0007192206263757819 =================
# ======================= 양봉전환 stick_size :: -82000.0 ================
# ============== 수익률 0.0008764902033432938 =================
# ======================= 음봉전환 stick_size :: 71000.0 ================
# ==============2022-02-23 08:30:00 음봉전환 ================
# ==============2022-02-23 08:30:00 이전 5분봉 크기 : -49000.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46340000.0 ######################################################
# ======================= 양봉전환 stick_size :: -57000.0 ================
# ============== 수익률 0.000847721378288253 =================
# ======================= 양봉전환 stick_size :: -297000.0 ================
# ============== 수익률 0.0014173441143778736 =================
# ======================= 양봉전환 stick_size :: -43000.0 ================
# ============== 수익률 0.0015017326678726346 =================
# ======================= 음봉전환 stick_size :: 95000.0 ================
# ==============2022-02-23 08:50:00 음봉전환 ================
# ==============2022-02-23 08:50:00 이전 5분봉 크기 : -81600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46666000.0 ######################################################
# ======================= 음봉전환 stick_size :: 97000.0 ================
# ==============2022-02-23 08:55:00 음봉전환 ================
# ==============2022-02-23 08:55:00 이전 5분봉 크기 : -46200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 97000.0, 이전5봉 : 46200.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 46571000.0 ######################################################
# ======================= 양봉전환 stick_size :: -68000.0 ================
# ============== 수익률 0.0013137763441797678 =================
# ======================= 양봉전환 stick_size :: -113000.0 ================
# ============== 수익률 0.00153817317960901 =================
# ======================= 음봉전환 stick_size :: 115000.0 ================
# ==============2022-02-23 09:10:00 음봉전환 ================
# ==============2022-02-23 09:10:00 이전 5분봉 크기 : -6400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 115000.0, 이전5봉 : 6400.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46685000.0 ######################################################
# ======================= 양봉전환 stick_size :: -16000.0 ================
# ============== 수익률 0.0013137763441797678 =================
# ======================= 음봉전환 stick_size :: 199000.0 ================
# ==============2022-02-23 09:20:00 음봉전환 ================
# ==============2022-02-23 09:20:00 이전 5분봉 크기 : 3000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 199000.0, 이전5봉 : 3000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46568000.0 ######################################################
# ======================= 양봉전환 stick_size :: -89000.0 ================
# ============== 수익률 0.001121984177146226 =================
# ======================= 음봉전환 stick_size :: 116000.0 ================
# ==============2022-02-23 09:30:00 음봉전환 ================
# ==============2022-02-23 09:30:00 이전 5분봉 크기 : 19200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 116000.0, 이전5봉 : 19200.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46468000.0 ######################################################
# ======================= 음봉전환 stick_size :: 82000.0 ================
# ==============2022-02-23 09:35:00 음봉전환 ================
# ==============2022-02-23 09:35:00 이전 5분봉 크기 : 65000.0 ============
# ###################################################### tic_count : 2, tic : 2, tic_start: 46352000.0 ######################################################
# ======================= 양봉전환 stick_size :: -75000.0 ================
# ============== 수익률 0.0008879977333653038 =================
# ======================= 양봉전환 stick_size :: -69000.0 ================
# ============== 수익률 0.00102033432861845 =================
# ======================= 양봉전환 stick_size :: -4000.0 ================
# ============== 수익률 0.0010280060152997848 =================
# ======================= 음봉전환 stick_size :: 39000.0 ================
# ==============2022-02-23 09:55:00 음봉전환 ================
# ==============2022-02-23 09:55:00 이전 5분봉 크기 : 10000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 39000.0, 이전5봉 : 10000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46419000.0 ######################################################
# ======================= 음봉전환 stick_size :: 29000.0 ================
# ==============2022-02-23 10:00:00 음봉전환 ================
# ==============2022-02-23 10:00:00 이전 5분봉 크기 : -5400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 29000.0, 이전5봉 : 5400.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 46380000.0 ######################################################
# ======================= 음봉전환 stick_size :: 11000.0 ================
# ==============2022-02-23 10:05:00 음봉전환 ================
# ==============2022-02-23 10:05:00 이전 5분봉 크기 : -16000.0 ============
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 2, tic_start: 46331000.0 ######################################################
# ======================= 양봉전환 stick_size :: -56000.0 ================
# ============== 수익률 0.0009455353834753695 =================
# ======================= 음봉전환 stick_size :: 97000.0 ================
# ==============2022-02-23 10:15:00 음봉전환 ================
# ==============2022-02-23 10:15:00 이전 5분봉 크기 : 3800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 97000.0, 이전5봉 : 3800.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46376000.0 ######################################################
# ======================= 양봉전환 stick_size :: -4000.0 ================
# ============== 수익률 0.0007633328247934921 =================
# ======================= 음봉전환 stick_size :: 46000.0 ================
# ==============2022-02-23 10:30:00 음봉전환 ================
# ==============2022-02-23 10:30:00 이전 5분봉 크기 : 9600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 46000.0, 이전5봉 : 9600.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46281000.0 ######################################################
# ======================= 양봉전환 stick_size :: -40000.0 ================
# ============== 수익률 0.000690451801320757 =================
# ======================= 음봉전환 stick_size :: 19000.0 ================
# ==============2022-02-23 10:40:00 음봉전환 ================
# ==============2022-02-23 10:40:00 이전 5분봉 크기 : 19800.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46243000.0 ######################################################
# ======================= 음봉전환 stick_size :: 101000.0 ================
# ==============2022-02-23 10:45:00 음봉전환 ================
# ==============2022-02-23 10:45:00 이전 5분봉 크기 : 4200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 101000.0, 이전5봉 : 4200.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 46224000.0 ######################################################
# ======================= 양봉전환 stick_size :: -43000.0 ================
# ============== 수익률 0.0005792123444413007 =================
# ======================= 양봉전환 stick_size :: -83000.0 ================
# ============== 수익률 0.0007383998430791425 =================
# ======================= 양봉전환 stick_size :: -32000.0 ================
# ============== 수익률 0.0007997733365298676 =================
# ======================= 양봉전환 stick_size :: -22000.0 ================
# ============== 수익률 0.000841967613277248 =================
# ======================= 양봉전환 stick_size :: -50000.0 ================
# ============== 수익률 0.0009378636967940189 =================
# ======================= 음봉전환 stick_size :: 60000.0 ================
# ==============2022-02-23 11:15:00 음봉전환 ================
# ==============2022-02-23 11:15:00 이전 5분봉 크기 : -46000.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46372000.0 ######################################################
# ======================= 음봉전환 stick_size :: 198000.0 ================
# ==============2022-02-23 11:20:00 음봉전환 ================
# ==============2022-02-23 11:20:00 이전 5분봉 크기 : -25400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 198000.0, 이전5봉 : 25400.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 46312000.0 ######################################################
# ======================= 음봉전환 stick_size :: 145000.0 ================
# ==============2022-02-23 11:25:00 음봉전환 ================
# ==============2022-02-23 11:25:00 이전 5분봉 크기 : 30800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 145000.0, 이전5봉 : 30800.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 2, tic_start: 45969000.0 ######################################################
# ======================= 음봉전환 stick_size :: 77000.0 ================
# ==============2022-02-23 11:30:00 음봉전환 ================
# ==============2022-02-23 11:30:00 이전 5분봉 크기 : 66200.0 ============
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ==================== 구매 tic : 3 ===============
# Buy KRW-BTC, KRW: 10088.76
# ======================== 2022-02-23 11:30:00 시간 매수 완료 : 45858000.0 ===============
# ============================= 2022-02-23 11:30:00 시간 가격 : 45858000.0, 매수평균 금액 : 45878000.0 ===============
# ###################################################### tic_count : 0, tic : 0, tic_start: 0 ######################################################
# ======================= 양봉전환 stick_size :: -36000.0 ================
# ============== 수익률 3.836261388900681e-05 =================
# ======================= 음봉전환 stick_size :: 72000.0 ================
# ==============2022-02-23 11:40:00 음봉전환 ================
# ==============2022-02-23 11:40:00 이전 5분봉 크기 : 88800.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 45894000.0 ######################################################
# ======================= 양봉전환 stick_size :: -4000.0 ================
# ============== 수익률 -0.00020619904965342548 =================
# ======================= 양봉전환 stick_size :: -3000.0 ================
# ============== 수익률 -0.00014865512881990733 =================
# ======================= 양봉전환 stick_size :: -9000.0 ================
# ============== 수익률 -0.0001270761585073519 =================
# ======================= 양봉전환 stick_size :: -60000.0 ================
# ============== 수익률 4.3157940625142575e-05 =================
# ======================= 음봉전환 stick_size :: 23000.0 ================
# ==============2022-02-23 12:05:00 음봉전환 ================
# ==============2022-02-23 12:05:00 이전 5분봉 크기 : -800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 23000.0, 이전5봉 : 800.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 45896000.0 ######################################################
# ======================= 양봉전환 stick_size :: -40000.0 ================
# ============== 수익률 8.391821788220934e-05 =================
# ======================= 음봉전환 stick_size :: 36000.0 ================
# ==============2022-02-23 12:15:00 음봉전환 ================
# ==============2022-02-23 12:15:00 이전 5분봉 크기 : -17800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 36000.0, 이전5봉 : 17800.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 45913000.0 ######################################################
# ======================= 양봉전환 stick_size :: -68000.0 ================
# ============== 수익률 0.00016064344566022297 =================
# ======================= 양봉전환 stick_size :: -105000.0 ================
# ============== 수익률 0.000347661188369153 =================
# ======================= 음봉전환 stick_size :: 37000.0 ================
# ==============2022-02-23 12:30:00 음봉전환 ================
# ==============2022-02-23 12:30:00 이전 5분봉 크기 : -30800.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46023000.0 ######################################################
# ======================= 양봉전환 stick_size :: -15000.0 ================
# ============== 수익률 0.0002949125942717706 =================
# ======================= 양봉전환 stick_size :: -23000.0 ================
# ============== 수익률 0.0003500588517372129 =================
# ======================= 음봉전환 stick_size :: 108000.0 ================
# ==============2022-02-23 12:45:00 음봉전환 ================
# ==============2022-02-23 12:45:00 이전 5분봉 크기 : -34800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 108000.0, 이전5봉 : 34800.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46024000.0 ######################################################
# ======================= 양봉전환 stick_size :: -12000.0 ================
# ============== 수익률 0.0001198831684031562 =================
# ======================= 음봉전환 stick_size :: 1000.0 ================
# ==============2022-02-23 12:55:00 음봉전환 ================
# ==============2022-02-23 12:55:00 이전 5분봉 크기 : 19000.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 45928000.0 ######################################################
# ======================= 양봉전환 stick_size :: -24000.0 ================
# ============== 수익률 0.00020380138628536555 =================
# ======================= 양봉전환 stick_size :: -75000.0 ================
# ============== 수익률 0.0003836261388900998 =================
# ======================= 양봉전환 stick_size :: -101000.0 ================
# ============== 수익률 0.0006209948123283523 =================
# ======================= 양봉전환 stick_size :: -44000.0 ================
# ============== 수익률 0.0007264920005231329 =================
# ======================= 음봉전환 stick_size :: 54000.0 ================
# ==============2022-02-23 13:20:00 음봉전환 ================
# ==============2022-02-23 13:20:00 이전 5분봉 크기 : -48600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46181000.0 ######################################################
# ======================= 음봉전환 stick_size :: 82000.0 ================
# ==============2022-02-23 13:25:00 음봉전환 ================
# ==============2022-02-23 13:25:00 이전 5분봉 크기 : -38000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 82000.0, 이전5봉 : 38000.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 46127000.0 ######################################################
# ======================= 양봉전환 stick_size :: -55000.0 ================
# ============== 수익률 0.0005322812677100072 =================
# ======================= 양봉전환 stick_size :: -68000.0 ================
# ============== 수익률 0.000695322376738306 =================
# ======================= 양봉전환 stick_size :: -33000.0 ================
# ============== 수익률 0.0007696499411482597 =================
# ======================= 음봉전환 stick_size :: 24000.0 ================
# ==============2022-02-23 13:45:00 음봉전환 ================
# ==============2022-02-23 13:45:00 이전 5분봉 크기 : -4000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 24000.0, 이전5봉 : 4000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46199000.0 ######################################################
# ======================= 양봉전환 stick_size :: -1000.0 ================
# ============== 수익률 0.0007145036836828173 =================
# ======================= 음봉전환 stick_size :: 2000.0 ================
# ==============2022-02-23 13:55:00 음봉전환 ================
# ==============2022-02-23 13:55:00 이전 5분봉 크기 : -26600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46176000.0 ######################################################
# ======================= 양봉전환 stick_size :: -24000.0 ================
# ============== 수익률 0.0007672522777801996 =================
# ======================= 양봉전환 stick_size :: -11000.0 ================
# ============== 수익률 0.0007936265748288908 =================
# ======================= 음봉전환 stick_size :: 65000.0 ================
# ==============2022-02-23 14:10:00 음봉전환 ================
# ==============2022-02-23 14:10:00 이전 5분봉 크기 : -2000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 65000.0, 이전5봉 : 2000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 46209000.0 ######################################################
# ======================= 음봉전환 stick_size :: 106000.0 ================
# ==============2022-02-23 14:15:00 음봉전환 ================
# ==============2022-02-23 14:15:00 이전 5분봉 크기 : 6200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 106000.0, 이전5봉 : 6200.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 46121000.0 ######################################################
# ======================= 음봉전환 stick_size :: 39000.0 ================
# ==============2022-02-23 14:20:00 음봉전환 ================
# ==============2022-02-23 14:20:00 이전 5분봉 크기 : 27600.0 ============
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ==================== 구매 tic : 3 ===============
# Buy KRW-BTC, KRW: 10114.720000000001
# ======================== 2022-02-23 14:20:00 시간 매수 완료 : 45976000.0 ===============
# ============================= 2022-02-23 14:20:00 시간 가격 : 45976000.0, 매수평균 금액 : 45894333.333333336 ===============
# ###################################################### tic_count : 0, tic : 0, tic_start: 0 ######################################################
# ======================= 양봉전환 stick_size :: -76000.0 ================
# ============== 수익률 0.0004534764640514704 =================
# ======================= 음봉전환 stick_size :: 1000.0 ================
# ==============2022-02-23 14:30:00 음봉전환 ================
# ==============2022-02-23 14:30:00 이전 5분봉 크기 : 24600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46052000.0 ######################################################
# ======================= 음봉전환 stick_size :: 23000.0 ================
# ==============2022-02-23 14:35:00 음봉전환 ================
# ==============2022-02-23 14:35:00 이전 5분봉 크기 : 27000.0 ============
# ###################################################### tic_count : 2, tic : 0, tic_start: 46051000.0 ######################################################
# ======================= 양봉전환 stick_size :: -38000.0 ================
# ============== 수익률 0.0004937428731215878 =================
# ======================= 양봉전환 stick_size :: -36000.0 ================
# ============== 수익률 0.000597285067873293 =================
# ======================= 양봉전환 stick_size :: -35000.0 ================
# ============== 수익률 0.0006921987463956908 =================
# ======================= 양봉전환 stick_size :: -25000.0 ================
# ============== 수익률 0.0007641030483066021 =================
# ======================= 양봉전환 stick_size :: -94000.0 ================
# ============== 수익률 0.0010344632234916323 =================
# ======================= 음봉전환 stick_size :: 27000.0 ================
# ==============2022-02-23 15:05:00 음봉전환 ================
# ==============2022-02-23 15:05:00 이전 5분봉 크기 : -45600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 46254000.0 ######################################################
# ======================= 양봉전환 stick_size :: -20000.0 ================
# ============== 수익률 0.0010172061910330174 =================
# ...
# ======================= 음봉전환 stick_size :: 168000.0 ================
# ==============2022-02-23 18:40:00 음봉전환 ================
# ==============2022-02-23 18:40:00 이전 5분봉 크기 : 17600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 168000.0, 이전5봉 : 17600.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 47232000.0 ######################################################
# ======================= 양봉전환 stick_size :: -71000.0 ================
# ============== 수익률 0.0035683708228321427 =================
# ======================= 양봉전환 stick_size :: -59000.0 ================
# ============== 수익률 0.0037351888032654676 =================
# ======================= 양봉전환 stick_size :: -23000.0 ================
# ============== 수익률 0.003801340761023507 =================
# ======================= 음봉전환 stick_size :: 8000.0 ================
# ==============2022-02-23 19:00:00 음봉전환 ================
# ==============2022-02-23 19:00:00 이전 5분봉 크기 : 2600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 8000.0, 이전5봉 : 2600.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 47216000.0 ######################################################
# ======================= 음봉전환 stick_size :: 70000.0 ================
# ==============2022-02-23 19:05:00 음봉전환 ================
# ==============2022-02-23 19:05:00 이전 5분봉 크기 : 4600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 70000.0, 이전5봉 : 4600.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 47203000.0 ######################################################
# ======================= 음봉전환 stick_size :: 129000.0 ================
# ==============2022-02-23 19:10:00 음봉전환 ================
# ==============2022-02-23 19:10:00 이전 5분봉 크기 : -15000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 129000.0, 이전5봉 : 15000.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ==================== 구매 tic : 3 ===============
# Buy KRW-BTC, KRW: 9876.51
# ======================== 2022-02-23 19:10:00 시간 매수 완료 : 47031000.0 ===============
# ============================= 2022-02-23 19:10:00 시간 가격 : 47031000.0, 매수평균 금액 : 46050346.40522876 ===============
# ###################################################### tic_count : 0, tic : 0, tic_start: 0 ######################################################
# ======================= 양봉전환 stick_size :: -48000.0 ================
# ============== 수익률 0.003603707962143744 =================
# ======================= 양봉전환 stick_size :: -49000.0 ================
# ============== 수익률 0.0037665080404325987 =================
# ======================= 음봉전환 stick_size :: 96000.0 ================
# ==============2022-02-23 19:25:00 음봉전환 ================
# ==============2022-02-23 19:25:00 이전 5분봉 크기 : 22000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 96000.0, 이전5봉 : 22000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 47184000.0 ######################################################
# ======================= 양봉전환 stick_size :: -23000.0 ================
# ============== 수익률 0.0036103528632983857 =================
# ======================= 양봉전환 stick_size :: -51000.0 ================
# ============== 수익률 0.003813022348515124 =================
# ======================= 음봉전환 stick_size :: 109000.0 ================
# ==============2022-02-23 19:45:00 음봉전환 ================
# ==============2022-02-23 19:45:00 이전 5분봉 크기 : -5400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 109000.0, 이전5봉 : 5400.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 47198000.0 ######################################################
# ======================= 음봉전환 stick_size :: 48000.0 ================
# ==============2022-02-23 19:50:00 음봉전환 ================
# ==============2022-02-23 19:50:00 이전 5분봉 크기 : 26200.0 ============
# ###################################################### tic_count : 2, tic : 2, tic_start: 47098000.0 ######################################################
# ======================= 양봉전환 stick_size :: -26000.0 ================
# ============== 수익률 0.0034043609275043268 =================
# ======================= 양봉전환 stick_size :: -25000.0 ================
# ============== 수익률 0.0034874221919374148 =================
# ======================= 음봉전환 stick_size :: 9000.0 ================
# ==============2022-02-23 20:05:00 음봉전환 ================
# ==============2022-02-23 20:05:00 이전 5분봉 크기 : 21200.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 47100000.0 ######################################################
# ======================= 음봉전환 stick_size :: 99000.0 ================
# ==============2022-02-23 20:10:00 음봉전환 ================
# ==============2022-02-23 20:10:00 이전 5분봉 크기 : 23000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 99000.0, 이전5봉 : 23000.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 47091000.0 ######################################################
# ======================= 양봉전환 stick_size :: -58000.0 ================
# ============== 수익률 0.003321299663071239 =================
# ======================= 음봉전환 stick_size :: 42000.0 ================
# ==============2022-02-23 20:20:00 음봉전환 ================
# ==============2022-02-23 20:20:00 이전 5분봉 크기 : -200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 42000.0, 이전5봉 : 200.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 47050000.0 ######################################################
# ======================= 양봉전환 stick_size :: -91000.0 ================
# ============== 수익률 0.0034840997413600936 =================
# ======================= 양봉전환 stick_size :: -1000.0 ================
# ============== 수익률 0.0034874221919374148 =================
# ======================= 양봉전환 stick_size :: -2000.0 ================
# ============== 수익률 0.0034940670930920883 =================
# ======================= 양봉전환 stick_size :: -97000.0 ================
# ============== 수익률 0.003816344799092445 =================
# ======================= 음봉전환 stick_size :: 18000.0 ================
# ==============2022-02-23 20:45:00 음봉전환 ================
# ==============2022-02-23 20:45:00 이전 5분봉 크기 : -29800.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 47199000.0 ######################################################
# ======================= 음봉전환 stick_size :: 106000.0 ================
# ==============2022-02-23 20:50:00 음봉전환 ================
# ==============2022-02-23 20:50:00 이전 5분봉 크기 : -34600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 106000.0, 이전5봉 : 34600.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 47182000.0 ######################################################
# ======================= 음봉전환 stick_size :: 47000.0 ================
# ==============2022-02-23 20:55:00 음봉전환 ================
# ==============2022-02-23 20:55:00 이전 5분봉 크기 : 4800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 47000.0, 이전5봉 : 4800.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 2, tic_start: 47040000.0 ######################################################
# ======================= 양봉전환 stick_size :: -30000.0 ================
# ============== 수익률 0.0035206466977106563 =================
# ======================= 양봉전환 stick_size :: -23000.0 ================
# ============== 수익률 0.003597063060989102 =================
# ======================= 음봉전환 stick_size :: 21000.0 ================
# ==============2022-02-23 21:10:00 음봉전환 ================
# ==============2022-02-23 21:10:00 이전 5분봉 크기 : 23600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 47133000.0 ######################################################
# ======================= 양봉전환 stick_size :: -43000.0 ================
# ============== 수익률 0.003650222270226269 =================
# ======================= 양봉전환 stick_size :: -31000.0 ================
# ============== 수익률 0.003716671281772752 =================
# ======================= 음봉전환 stick_size :: 3000.0 ================
# ==============2022-02-23 21:25:00 음봉전환 ================
# ==============2022-02-23 21:25:00 이전 5분봉 크기 : -21200.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 47169000.0 ######################################################
# ======================= 양봉전환 stick_size :: -40000.0 ================
# ============== 수익률 0.0038528917554430074 =================
# ======================= 양봉전환 stick_size :: -44000.0 ================
# ============== 수익률 0.004015691833731862 =================
# ======================= 양봉전환 stick_size :: -33000.0 ================
# ============== 수익률 0.004125332702783549 =================
# ======================= 양봉전환 stick_size :: -38000.0 ================
# ============== 수익률 0.004254908275299163 =================
# ======================= 양봉전환 stick_size :: -50000.0 ================
# ============== 수익률 0.004364549144350818 =================
# ======================= 양봉전환 stick_size :: -58000.0 ================
# ============== 수익률 0.004477512463979826 =================
# ======================= 음봉전환 stick_size :: 90000.0 ================
# ==============2022-02-23 22:00:00 음봉전환 ================
# ==============2022-02-23 22:00:00 이전 5분봉 크기 : -44600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 90000.0, 이전5봉 : 44600.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 47398000.0 ######################################################
# ======================= 양봉전환 stick_size :: -57000.0 ================
# ============== 수익률 0.004274842978763088 =================
# ======================= 양봉전환 stick_size :: -63000.0 ================
# ============== 수익률 0.004484157365134469 =================
# ======================= 양봉전환 stick_size :: -69000.0 ================
# ============== 수익률 0.004723373806701769 =================
# ======================= 음봉전환 stick_size :: 169000.0 ================
# ==============2022-02-23 22:20:00 음봉전환 ================
# ==============2022-02-23 22:20:00 이전 5분봉 크기 : -31400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 169000.0, 이전5봉 : 31400.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 47472000.0 ######################################################
# ======================= 음봉전환 stick_size :: 24000.0 ================
# ==============2022-02-23 22:25:00 음봉전환 ================
# ==============2022-02-23 22:25:00 이전 5분봉 크기 : 14000.0 ============
# ###################################################### tic_count : 2, tic : 2, tic_start: 47303000.0 ######################################################
# ======================= 음봉전환 stick_size :: 45000.0 ================
# ==============2022-02-23 22:30:00 음봉전환 ================
# ==============2022-02-23 22:30:00 이전 5분봉 크기 : 800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 45000.0, 이전5봉 : 800.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ==================== 구매 tic : 3 ===============
# Buy KRW-BTC, KRW: 9918.51
# ======================== 2022-02-23 22:30:00 시간 매수 완료 : 47231000.0 ===============
# ============================= 2022-02-23 22:30:00 시간 가격 : 47231000.0, 매수평균 금액 : 46192839.08045976 ===============
# ###################################################### tic_count : 0, tic : 0, tic_start: 0 ######################################################
# ======================= 음봉전환 stick_size :: 46000.0 ================
# ==============2022-02-23 22:35:00 음봉전환 ================
# ==============2022-02-23 22:35:00 이전 5분봉 크기 : 21200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 46000.0, 이전5봉 : 21200.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 47231000.0 ######################################################
# ======================= 양봉전환 stick_size :: -13000.0 ================
# ============== 수익률 0.0037900246766616164 =================
# ======================= 양봉전환 stick_size :: -1000.0 ================
# ============== 수익률 0.0037900246766616164 =================
# ======================= 음봉전환 stick_size :: 53000.0 ================
# ==============2022-02-23 22:50:00 음봉전환 ================
# ==============2022-02-23 22:50:00 이전 5분봉 크기 : 20200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 53000.0, 이전5봉 : 20200.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 47199000.0 ######################################################
# ======================= 양봉전환 stick_size :: -68000.0 ================
# ============== 수익률 0.0038427601232912762 =================
# ======================= 양봉전환 stick_size :: -13000.0 ================
# ============== 수익률 0.003891728752304521 =================
# ======================= 음봉전환 stick_size :: 128000.0 ================
# ==============2022-02-23 23:05:00 음봉전환 ================
# ==============2022-02-23 23:05:00 이전 5분봉 크기 : -8400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 128000.0, 이전5봉 : 8400.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 47226000.0 ######################################################
# ======================= 음봉전환 stick_size :: 103000.0 ================
# ==============2022-02-23 23:10:00 음봉전환 ================
# ==============2022-02-23 23:10:00 이전 5분봉 크기 : 19800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 103000.0, 이전5봉 : 19800.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 47098000.0 ######################################################
# ======================= 양봉전환 stick_size :: -81000.0 ================
# ============== 수익률 0.0033342397450767227 =================
# ======================= 양봉전환 stick_size :: -45000.0 ================
# ============== 수익률 0.0035037465378148862 =================
# ======================= 음봉전환 stick_size :: 16000.0 ================
# ==============2022-02-23 23:25:00 음봉전환 ================
# ==============2022-02-23 23:25:00 이전 5분봉 크기 : 18400.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 47123000.0 ######################################################
# ======================= 양봉전환 stick_size :: -107000.0 ================
# ============== 수익률 0.0038389933056748606 =================
# ======================= 양봉전환 stick_size :: -35000.0 ================
# ============== 수익률 0.003820159217592846 =================
# ======================= 음봉전환 stick_size :: 87000.0 ================
# ==============2022-02-23 23:40:00 음봉전환 ================
# ==============2022-02-23 23:40:00 이전 5분봉 크기 : -50400.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 47207000.0 ######################################################
# ======================= 음봉전환 stick_size :: 1000.0 ================
# ==============2022-02-23 23:45:00 음봉전환 ================
# ==============2022-02-23 23:45:00 이전 5분봉 크기 : -16800.0 ============
# ###################################################### tic_count : 2, tic : 1, tic_start: 47120000.0 ######################################################
# ======================= 음봉전환 stick_size :: 177000.0 ================
# ==============2022-02-23 23:50:00 음봉전환 ================
# ==============2022-02-23 23:50:00 이전 5분봉 크기 : -7600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 177000.0, 이전5봉 : 7600.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 2, tic_start: 46906000.0 ######################################################
# 0.10615122300001094 % !!!!!
# 0.10615122300001094

# %%
# 0.1 => 0.03 %
# 0.05 => 0.019 %
# 한달 0.05 => -5.4
# 한달 0.1 => -4.11
# 한달 0.5 => -1.75
# 고친 후 한달 0.05 => 0.21074215800003146
