# %%
import pandas as pd
import pyupbit

# %%
import time

# %%
df2 = pyupbit.get_ohlcv('KRW-BTC', 'minute5', to='20220323 00:00:00', count=288)

# %%
df2 = pyupbit.get_ohlcv('KRW-BTC', 'minute5', to='20220224 00:00:00', count=8928)

# %%
# df2.head()

# %%
df2_reset = df2.reset_index()
df2_reset.columns = ['timestamp', 'open', 'high', 'low', 'close', 'volume', 'value']

# %%
# df = pd.read_csv('./data/data.csv')

# %%
# df.head()

# %%
df2_reset.head()
# Out:
#             timestamp        open        high         low       close  \
# 0 2022-03-22 00:00:00  50194000.0  50256000.0  50170000.0  50170000.0
# 1 2022-03-22 00:05:00  50170000.0  50177000.0  50100000.0  50105000.0
# 2 2022-03-22 00:10:00  50107000.0  50195000.0  50099000.0  50154000.0
# 3 2022-03-22 00:15:00  50154000.0  50276000.0  50152000.0  50236000.0
# 4 2022-03-22 00:20:00  50259000.0  50259000.0  50163000.0  50248000.0
#
#       volume         value
# 0  14.102482  7.081985e+08
# 1  12.701553  6.366338e+08
# 2   8.876366  4.449087e+08
# 3   9.914677  4.981722e+08
# 4  11.128746  5.590940e+08

# %%
from upbit_backtest import backtesting

# %%
backtesting(df2_reset)
# Out:
# ======================= 음봉전환 stick_size :: 24000.0 ================
# ==============2022-03-22 00:00:00 음봉전환 ================
# ==============2022-03-22 00:00:00 이전 5분봉 크기 : -23200.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 52043000.0 ######################################################
# ======================= 음봉전환 stick_size :: 65000.0 ================
# ==============2022-03-22 00:05:00 음봉전환 ================
# ==============2022-03-22 00:05:00 이전 5분봉 크기 : -6200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 65000.0, 이전5봉 : 6200.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 50170000.0 ######################################################
# ======================= 양봉전환 stick_size :: -47000.0 ================
# ======================= 양봉전환 stick_size :: -82000.0 ================
# ======================= 음봉전환 stick_size :: 11000.0 ================
# ==============2022-03-22 00:20:00 음봉전환 ================
# ==============2022-03-22 00:20:00 이전 5분봉 크기 : -24800.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50236000.0 ######################################################
# ======================= 음봉전환 stick_size :: 5000.0 ================
# ==============2022-03-22 00:25:00 음봉전환 ================
# ==============2022-03-22 00:25:00 이전 5분봉 크기 : -5800.0 ============
# ###################################################### tic_count : 2, tic : 0, tic_start: 50248000.0 ######################################################
# ======================= 양봉전환 stick_size :: -49000.0 ================
# ======================= 양봉전환 stick_size :: -56000.0 ================
# ======================= 음봉전환 stick_size :: 73000.0 ================
# ==============2022-03-22 00:40:00 음봉전환 ================
# ==============2022-03-22 00:40:00 이전 5분봉 크기 : -34200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 73000.0, 이전5봉 : 34200.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 50319000.0 ######################################################
# ======================= 양봉전환 stick_size :: -44000.0 ================
# ======================= 양봉전환 stick_size :: -52000.0 ================
# ======================= 음봉전환 stick_size :: 4000.0 ================
# ==============2022-03-22 00:55:00 음봉전환 ================
# ==============2022-03-22 00:55:00 이전 5분봉 크기 : -25600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50312000.0 ######################################################
# ======================= 음봉전환 stick_size :: 43000.0 ================
# ==============2022-03-22 01:00:00 음봉전환 ================
# ==============2022-03-22 01:00:00 이전 5분봉 크기 : -15000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 43000.0, 이전5봉 : 15000.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 50316000.0 ######################################################
# ======================= 음봉전환 stick_size :: 27000.0 ================
# ==============2022-03-22 01:05:00 음봉전환 ================
# ==============2022-03-22 01:05:00 이전 5분봉 크기 : 4800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 27000.0, 이전5봉 : 4800.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 2, tic_start: 50247000.0 ######################################################
# ======================= 음봉전환 stick_size :: 18000.0 ================
# ==============2022-03-22 01:10:00 음봉전환 ================
# ==============2022-03-22 01:10:00 이전 5분봉 크기 : -4400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 18000.0, 이전5봉 : 4400.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 4, tic : 2, tic_start: 50247000.0 ######################################################
# ======================= 음봉전환 stick_size :: 87000.0 ================
# ==============2022-03-22 01:15:00 음봉전환 ================
# ==============2022-03-22 01:15:00 이전 5분봉 크기 : 8000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 87000.0, 이전5봉 : 8000.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ==================== 구매 tic : 3 ===============
# Buy KRW-BTC, KRW: 10028.4
# ======================== 2022-03-22 01:15:00 시간 매수 완료 : 50142000.0 ===============
# ============================= 2022-03-22 01:15:00 시간 가격 : 50142000.0, 매수평균 금액 : 50141999.99999999 ===============
# ###################################################### tic_count : 0, tic : 0, tic_start: 0 ######################################################
# ======================= 양봉전환 stick_size :: -48000.0 ================
# ============== 수익률 2.5128634677516584e-05 =================
# ======================= 양봉전환 stick_size :: -34000.0 ================
# ============== 수익률 3.8690120059035254e-05 =================
# ======================= 음봉전환 stick_size :: 124000.0 ================
# ==============2022-03-22 01:30:00 음봉전환 ================
# ==============2022-03-22 01:30:00 이전 5분봉 크기 : 10000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 124000.0, 이전5봉 : 10000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 50239000.0 ######################################################
# ======================= 음봉전환 stick_size :: 10000.0 ================
# ==============2022-03-22 01:35:00 음봉전환 ================
# ==============2022-03-22 01:35:00 이전 5분봉 크기 : 29400.0 ============
# ###################################################### tic_count : 2, tic : 1, tic_start: 50060000.0 ######################################################
# ======================= 음봉전환 stick_size :: 43000.0 ================
# ==============2022-03-22 01:40:00 음봉전환 ================
# ==============2022-03-22 01:40:00 이전 5분봉 크기 : 27800.0 ============
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 2, tic_start: 50007000.0 ######################################################
# ======================= 음봉전환 stick_size :: 31000.0 ================
# ==============2022-03-22 01:45:00 음봉전환 ================
# ==============2022-03-22 01:45:00 이전 5분봉 크기 : 19000.0 ============
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ==================== 구매 tic : 3 ===============
# Buy KRW-BTC, KRW: 9995.0
# ======================== 2022-03-22 01:45:00 시간 매수 완료 : 49975000.0 ===============
# ============================= 2022-03-22 01:45:00 시간 가격 : 49975000.0, 매수평균 금액 : 50058500.0 ===============
# ###################################################### tic_count : 0, tic : 0, tic_start: 0 ######################################################
# ======================= 음봉전환 stick_size :: 66000.0 ================
# ==============2022-03-22 01:50:00 음봉전환 ================
# ==============2022-03-22 01:50:00 이전 5분봉 크기 : 34800.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 49975000.0 ######################################################
# ======================= 양봉전환 stick_size :: -39000.0 ================
# ============== 수익률 -6.991819571101811e-05 =================
# ======================= 양봉전환 stick_size :: -28000.0 ================
# ============== 수익률 -5.713315420957916e-05 =================
# ======================= 양봉전환 stick_size :: -42000.0 ================
# ============== 수익률 -2.676868064364984e-05 =================
# ======================= 음봉전환 stick_size :: 23000.0 ================
# ==============2022-03-22 02:10:00 음봉전환 ================
# ==============2022-03-22 02:10:00 이전 5분봉 크기 : -2400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 23000.0, 이전5봉 : 2400.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 50025000.0 ######################################################
# ======================= 음봉전환 stick_size :: 37000.0 ================
# ==============2022-03-22 02:15:00 음봉전환 ================
# ==============2022-03-22 02:15:00 이전 5분봉 크기 : -4000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 37000.0, 이전5봉 : 4000.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 50005000.0 ######################################################
# ======================= 양봉전환 stick_size :: -48000.0 ================
# ============== 수익률 -2.7567745737485685e-05 =================
# ======================= 양봉전환 stick_size :: -28000.0 ================
# ============== 수익률 1.558176932988258e-05 =================
# ======================= 양봉전환 stick_size :: -64000.0 ================
# ============== 수익률 6.752100042949603e-05 =================
# ======================= 음봉전환 stick_size :: 20000.0 ================
# ==============2022-03-22 02:35:00 음봉전환 ================
# ==============2022-03-22 02:35:00 이전 5분봉 크기 : -16000.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50143000.0 ######################################################
# ======================= 음봉전환 stick_size :: 59000.0 ================
# ==============2022-03-22 02:40:00 음봉전환 ================
# ==============2022-03-22 02:40:00 이전 5분봉 크기 : -16600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 59000.0, 이전5봉 : 16600.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 50121000.0 ######################################################
# ======================= 양봉전환 stick_size :: -102000.0 ================
# ============== 수익률 6.592287024181707e-05 =================
# ======================= 음봉전환 stick_size :: 57000.0 ================
# ==============2022-03-22 02:50:00 음봉전환 ================
# ==============2022-03-22 02:50:00 이전 5분봉 크기 : -23000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 57000.0, 이전5봉 : 23000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 50141000.0 ######################################################
# ======================= 음봉전환 stick_size :: 7000.0 ================
# ==============2022-03-22 02:55:00 음봉전환 ================
# ==============2022-03-22 02:55:00 이전 5분봉 크기 : -6000.0 ============
# ###################################################### tic_count : 2, tic : 1, tic_start: 50109000.0 ######################################################
# ======================= 음봉전환 stick_size :: 9000.0 ================
# ==============2022-03-22 03:00:00 음봉전환 ================
# ==============2022-03-22 03:00:00 이전 5분봉 크기 : 8200.0 ============
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 1, tic_start: 50102000.0 ######################################################
# ======================= 양봉전환 stick_size :: -2000.0 ================
# ============== 수익률 5.9530349491093964e-05 =================
# ======================= 양봉전환 stick_size :: -5000.0 ================
# ============== 수익률 5.9530349491093964e-05 =================
# ======================= 음봉전환 stick_size :: 13000.0 ================
# ==============2022-03-22 03:15:00 음봉전환 ================
# ==============2022-03-22 03:15:00 이전 5분봉 크기 : 13200.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50133000.0 ######################################################
# ======================= 양봉전환 stick_size :: -71000.0 ================
# ============== 수익률 0.00010587612493382742 =================
# ======================= 음봉전환 stick_size :: 19000.0 ================
# ==============2022-03-22 03:25:00 음봉전환 ================
# ==============2022-03-22 03:25:00 이전 5분봉 크기 : -11200.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50191000.0 ######################################################
# ======================= 양봉전환 stick_size :: -7000.0 ================
# ============== 수익률 9.628734380774639e-05 =================
# ======================= 음봉전환 stick_size :: 27000.0 ================
# ==============2022-03-22 03:35:00 음봉전환 ================
# ==============2022-03-22 03:35:00 이전 5분봉 크기 : -10200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 27000.0, 이전5봉 : 10200.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 50179000.0 ######################################################
# ======================= 음봉전환 stick_size :: 47000.0 ================
# ==============2022-03-22 03:40:00 음봉전환 ================
# ==============2022-03-22 03:40:00 이전 5분봉 크기 : -3800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 47000.0, 이전5봉 : 3800.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 50152000.0 ######################################################
# ======================= 음봉전환 stick_size :: 81000.0 ================
# ==============2022-03-22 03:45:00 음봉전환 ================
# ==============2022-03-22 03:45:00 이전 5분봉 크기 : 3000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 81000.0, 이전5봉 : 3000.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ==================== 구매 tic : 3 ===============
# Buy KRW-BTC, KRW: 10008.0
# ======================== 2022-03-22 03:45:00 시간 매수 완료 : 50040000.0 ===============
# ============================= 2022-03-22 03:45:00 시간 가격 : 50040000.0, 매수평균 금액 : 50052333.33333333 ===============
# ###################################################### tic_count : 0, tic : 0, tic_start: 0 ######################################################
# ======================= 음봉전환 stick_size :: 19000.0 ================
# ==============2022-03-22 03:50:00 음봉전환 ================
# ==============2022-03-22 03:50:00 이전 5분봉 크기 : 33400.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50040000.0 ######################################################
# ======================= 음봉전환 stick_size :: 17000.0 ================
# ==============2022-03-22 03:55:00 음봉전환 ================
# ==============2022-03-22 03:55:00 이전 5분봉 크기 : 33400.0 ============
# ###################################################### tic_count : 2, tic : 0, tic_start: 50021000.0 ######################################################
# ======================= 양봉전환 stick_size :: -2000.0 ================
# ============== 수익률 -4.8349394300626195e-05 =================
# ======================= 음봉전환 stick_size :: 14000.0 ================
# ==============2022-03-22 04:05:00 음봉전환 ================
# ==============2022-03-22 04:05:00 이전 5분봉 크기 : 32400.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50012000.0 ######################################################
# ======================= 음봉전환 stick_size :: 28000.0 ================
# ==============2022-03-22 04:10:00 음봉전환 ================
# ==============2022-03-22 04:10:00 이전 5분봉 크기 : 25800.0 ============
# ###################################################### tic_count : 2, tic : 1, tic_start: 49998000.0 ######################################################
# ======================= 양봉전환 stick_size :: -11000.0 ================
# ============== 수익률 -8.551049901103367e-05 =================
# ======================= 양봉전환 stick_size :: -62000.0 ================
# ============== 수익률 -9.989544276990084e-06 =================
# ======================= 양봉전환 stick_size :: -15000.0 ================
# ============== 수익률 7.991635421592068e-06 =================
# ======================= 양봉전환 stick_size :: -88000.0 ================
# ============== 수익률 7.51213729629698e-05 =================
# ======================= 양봉전환 stick_size :: -64000.0 ================
# ============== 수익률 0.0001506423276970134 =================
# ======================= 음봉전환 stick_size :: 30000.0 ================
# ==============2022-03-22 04:40:00 음봉전환 ================
# ==============2022-03-22 04:40:00 이전 5분봉 크기 : -48000.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50178000.0 ######################################################
# ======================= 음봉전환 stick_size :: 61000.0 ================
# ==============2022-03-22 04:45:00 음봉전환 ================
# ==============2022-03-22 04:45:00 이전 5분봉 크기 : -39800.0 ============
# ###################################################### tic_count : 2, tic : 1, tic_start: 50148000.0 ######################################################
# ======================= 양봉전환 stick_size :: -61000.0 ================
# ============== 수익률 0.00011467996829984908 =================
# ======================= 양봉전환 stick_size :: -46000.0 ================
# ============== 수익률 0.00016982225270883143 =================
# ======================= 음봉전환 stick_size :: 17000.0 ================
# ==============2022-03-22 05:00:00 음봉전환 ================
# ==============2022-03-22 05:00:00 이전 5분봉 크기 : -16000.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50194000.0 ######################################################
# ======================= 양봉전환 stick_size :: -17000.0 ================
# ============== 수익률 0.0001506423276970134 =================
# ======================= 양봉전환 stick_size :: -7000.0 ================
# ============== 수익률 0.00017102099802207462 =================
# ======================= 음봉전환 stick_size :: 37000.0 ================
# ==============2022-03-22 05:15:00 음봉전환 ================
# ==============2022-03-22 05:15:00 이전 5분봉 크기 : -22800.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50195000.0 ######################################################
# ======================= 양봉전환 stick_size :: -30000.0 ================
# ============== 수익률 0.00015303981832349246 =================
# ======================= 음봉전환 stick_size :: 4000.0 ================
# ==============2022-03-22 05:25:00 음봉전환 ================
# ==============2022-03-22 05:25:00 이전 5분봉 크기 : 0.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 4000.0, 이전5봉 : 0.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 50180000.0 ######################################################
# ======================= 음봉전환 stick_size :: 1000.0 ================
# ==============2022-03-22 05:30:00 음봉전환 ================
# ==============2022-03-22 05:30:00 이전 5분봉 크기 : -2600.0 ============
# ###################################################### tic_count : 2, tic : 1, tic_start: 50176000.0 ######################################################
# ======================= 양봉전환 stick_size :: -8000.0 ================
# ============== 수익률 0.00015783479957644334 =================
# ======================= 양봉전환 stick_size :: -36000.0 ================
# ============== 수익률 0.00020218837616628078 =================
# ======================= 음봉전환 stick_size :: 17000.0 ================
# ==============2022-03-22 05:45:00 음봉전환 ================
# ==============2022-03-22 05:45:00 이전 5분봉 크기 : -13800.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50221000.0 ######################################################
# ======================= 양봉전환 stick_size :: -29000.0 ================
# ============== 수익률 0.00027770933090032435 =================
# ======================= 음봉전환 stick_size :: 128000.0 ================
# ==============2022-03-22 05:55:00 음봉전환 ================
# ==============2022-03-22 05:55:00 이전 5분봉 크기 : -11000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 128000.0, 이전5봉 : 11000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 50284000.0 ######################################################
# ======================= 음봉전환 stick_size :: 54000.0 ================
# ==============2022-03-22 06:00:00 음봉전환 ================
# ==============2022-03-22 06:00:00 이전 5분봉 크기 : 14400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 54000.0, 이전5봉 : 14400.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 50154000.0 ######################################################
# ======================= 음봉전환 stick_size :: 20000.0 ================
# ==============2022-03-22 06:05:00 음봉전환 ================
# ==============2022-03-22 06:05:00 이전 5분봉 크기 : 26800.0 ============
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 2, tic_start: 50100000.0 ######################################################
# ======================= 양봉전환 stick_size :: -18000.0 ================
# ============== 수익률 9.9096279227746e-05 =================
# ======================= 양봉전환 stick_size :: -13000.0 ================
# ============== 수익률 0.00010868624173365503 =================
# ======================= 양봉전환 stick_size :: -106000.0 ================
# ============== 수익률 0.0002345544996237301 =================
# ======================= 음봉전환 stick_size :: 18000.0 ================
# ==============2022-03-22 06:25:00 음봉전환 ================
# ==============2022-03-22 06:25:00 이전 5분봉 크기 : -12600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50248000.0 ######################################################
# ======================= 음봉전환 stick_size :: 44000.0 ================
# ==============2022-03-22 06:30:00 음봉전환 ================
# ==============2022-03-22 06:30:00 이전 5분봉 크기 : -19800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 44000.0, 이전5봉 : 19800.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 50230000.0 ######################################################
# ======================= 양봉전환 stick_size :: -39000.0 ================
# ============== 수익률 0.00020698335741923892 =================
# ======================= 음봉전환 stick_size :: 17000.0 ================
# ==============2022-03-22 06:40:00 음봉전환 ================
# ==============2022-03-22 06:40:00 이전 5분봉 크기 : -19200.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50225000.0 ######################################################
# ======================= 음봉전환 stick_size :: 6000.0 ================
# ==============2022-03-22 06:45:00 음봉전환 ================
# ==============2022-03-22 06:45:00 이전 5분봉 크기 : -13200.0 ============
# ###################################################### tic_count : 2, tic : 1, tic_start: 50208000.0 ######################################################
# ======================= 양봉전환 stick_size :: -82000.0 ================
# ============== 수익률 0.0002968892559121497 =================
# ======================= 양봉전환 stick_size :: -13000.0 ================
# ============== 수익률 0.00031247294498425274 =================
# ======================= 양봉전환 stick_size :: -56000.0 ================
# ============== 수익률 0.0003796026825256232 =================
# ======================= 양봉전환 stick_size :: -16000.0 ================
# ============== 수익률 0.00039518637159773355 =================
# ======================= 음봉전환 stick_size :: 5000.0 ================
# ==============2022-03-22 07:10:00 음봉전환 ================
# ==============2022-03-22 07:10:00 이전 5분봉 크기 : -32200.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50382000.0 ######################################################
# ======================= 음봉전환 stick_size :: 45000.0 ================
# ==============2022-03-22 07:15:00 음봉전환 ================
# ==============2022-03-22 07:15:00 이전 5분봉 크기 : -32400.0 ============
# ###################################################### tic_count : 2, tic : 1, tic_start: 50375000.0 ######################################################
# ======================= 음봉전환 stick_size :: 41000.0 ================
# ==============2022-03-22 07:20:00 음봉전환 ================
# ==============2022-03-22 07:20:00 이전 5분봉 크기 : -7000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 41000.0, 이전5봉 : 7000.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 2, tic_start: 50284000.0 ######################################################
# ======================= 음봉전환 stick_size :: 38000.0 ================
# ==============2022-03-22 07:25:00 음봉전환 ================
# ==============2022-03-22 07:25:00 이전 5분봉 크기 : 3800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 38000.0, 이전5봉 : 3800.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ==================== 구매 tic : 3 ===============
# Buy KRW-BTC, KRW: 10048.800000000001
# ======================== 2022-03-22 07:25:00 시간 매수 완료 : 50244000.0 ===============
# ============================= 2022-03-22 07:25:00 시간 가격 : 50244000.0, 매수평균 금액 : 50100250.0 ===============
# ###################################################### tic_count : 0, tic : 0, tic_start: 0 ######################################################
# ======================= 음봉전환 stick_size :: 2000.0 ================
# ==============2022-03-22 07:30:00 음봉전환 ================
# ==============2022-03-22 07:30:00 이전 5분봉 크기 : 22600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50244000.0 ######################################################
# ======================= 음봉전환 stick_size :: 20000.0 ================
# ==============2022-03-22 07:40:00 음봉전환 ================
# ==============2022-03-22 07:40:00 이전 5분봉 크기 : 25200.0 ============
# ###################################################### tic_count : 2, tic : 0, tic_start: 50250000.0 ######################################################
# ======================= 양봉전환 stick_size :: -12000.0 ================
# ============== 수익률 0.00022634617591727423 =================
# ======================= 음봉전환 stick_size :: 2000.0 ================
# ==============2022-03-22 07:50:00 음봉전환 ================
# ==============2022-03-22 07:50:00 이전 5분봉 크기 : 9600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50242000.0 ######################################################
# ======================= 음봉전환 stick_size :: 21000.0 ================
# ==============2022-03-22 07:55:00 음봉전환 ================
# ==============2022-03-22 07:55:00 이전 5분봉 크기 : 2400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 21000.0, 이전5봉 : 2400.0 ==========
# ###################################################### tic_count : 2, tic : 0, tic_start: 50229000.0 ######################################################
# ======================= 음봉전환 stick_size :: 39000.0 ================
# ==============2022-03-22 08:00:00 음봉전환 ================
# ==============2022-03-22 08:00:00 이전 5분봉 크기 : 6200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 39000.0, 이전5봉 : 6200.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 1, tic_start: 50169000.0 ######################################################
# ======================= 양봉전환 stick_size :: -22000.0 ================
# ============== 수익률 0.00014650625495879596 =================
# ======================= 음봉전환 stick_size :: 12000.0 ================
# ==============2022-03-22 08:10:00 음봉전환 ================
# ==============2022-03-22 08:10:00 이전 5분봉 크기 : 5600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 12000.0, 이전5봉 : 5600.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 50192000.0 ######################################################
# ======================= 음봉전환 stick_size :: 42000.0 ================
# ==============2022-03-22 08:15:00 음봉전환 ================
# ==============2022-03-22 08:15:00 이전 5분봉 크기 : 10400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 42000.0, 이전5봉 : 10400.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 50182000.0 ######################################################
# ======================= 음봉전환 stick_size :: 5000.0 ================
# ==============2022-03-22 08:20:00 음봉전환 ================
# ==============2022-03-22 08:20:00 이전 5분봉 크기 : 18400.0 ============
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 2, tic_start: 50140000.0 ######################################################
# ======================= 음봉전환 stick_size :: 25000.0 ================
# ==============2022-03-22 08:25:00 음봉전환 ================
# ==============2022-03-22 08:25:00 이전 5분봉 크기 : 15200.0 ============
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 4, tic : 2, tic_start: 50135000.0 ######################################################
# ======================= 양봉전환 stick_size :: -19000.0 ================
# ============== 수익률 2.9939970359429343e-05 =================
# ======================= 양봉전환 stick_size :: -26000.0 ================
# ============== 수익률 0.00012574787550960324 =================
# ======================= 음봉전환 stick_size :: 22000.0 ================
# ==============2022-03-22 08:40:00 음봉전환 ================
# ==============2022-03-22 08:40:00 이전 5분봉 크기 : 5400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 22000.0, 이전5봉 : 5400.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 50179000.0 ######################################################
# ======================= 양봉전환 stick_size :: -38000.0 ================
# ============== 수익률 0.00015129665021630756 =================
# ======================= 음봉전환 stick_size :: 21000.0 ================
# ==============2022-03-22 08:55:00 음봉전환 ================
# ==============2022-03-22 08:55:00 이전 5분봉 크기 : -12200.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50195000.0 ######################################################
# ======================= 양봉전환 stick_size :: -51000.0 ================
# ============== 수익률 0.00012574787550960324 =================
# ======================= 음봉전환 stick_size :: 99000.0 ================
# ==============2022-03-22 09:10:00 음봉전환 ================
# ==============2022-03-22 09:10:00 이전 5분봉 크기 : -13600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 99000.0, 이전5봉 : 13600.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 50179000.0 ######################################################
# ======================= 양봉전환 stick_size :: -58000.0 ================
# ============== 수익률 6.027914032364527e-05 =================
# ======================= 음봉전환 stick_size :: 53000.0 ================
# ==============2022-03-22 09:20:00 음봉전환 ================
# ==============2022-03-22 09:20:00 이전 5분봉 크기 : 2200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 53000.0, 이전5봉 : 2200.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 50138000.0 ######################################################
# ======================= 음봉전환 stick_size :: 27000.0 ================
# ==============2022-03-22 09:25:00 음봉전환 ================
# ==============2022-03-22 09:25:00 이전 5분봉 크기 : 8600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 27000.0, 이전5봉 : 8600.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 50085000.0 ######################################################
# ======================= 양봉전환 stick_size :: -12000.0 ================
# ============== 수익률 -4.989995059904891e-05 =================
# ======================= 양봉전환 stick_size :: -30000.0 ================
# ============== 수익률 -1.9959980239619564e-06 =================
# ======================= 양봉전환 stick_size :: -97000.0 ================
# ============== 수익률 0.0001544902470546438 =================
# ======================= 양봉전환 stick_size :: -28000.0 ================
# ============== 수익률 0.00019760380437223367 =================
# ======================= 양봉전환 stick_size :: -65000.0 ================
# ============== 수익률 0.00029341170952240756 =================
# ======================= 양봉전환 stick_size :: -4000.0 ================
# ============== 수익률 0.00029979890319908 =================
# ======================= 음봉전환 stick_size :: 1000.0 ================
# ==============2022-03-22 10:00:00 음봉전환 ================
# ==============2022-03-22 10:00:00 이전 5분봉 크기 : -44800.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50288000.0 ######################################################
# ======================= 음봉전환 stick_size :: 7000.0 ================
# ==============2022-03-22 10:05:00 음봉전환 ================
# ==============2022-03-22 10:05:00 이전 5분봉 크기 : -38600.0 ============
# ###################################################### tic_count : 2, tic : 0, tic_start: 50287000.0 ######################################################
# ======================= 양봉전환 stick_size :: -38000.0 ================
# ============== 수익률 0.00034929965419334236 =================
# ======================= 음봉전환 stick_size :: 43000.0 ================
# ==============2022-03-22 10:15:00 음봉전환 ================
# ==============2022-03-22 10:15:00 이전 5분봉 크기 : -19800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 43000.0, 이전5봉 : 19800.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 50319000.0 ######################################################
# ======================= 양봉전환 stick_size :: -21000.0 ================
# ============== 수익률 0.000347702855774167 =================
# ======================= 음봉전환 stick_size :: 85000.0 ================
# ==============2022-03-22 10:25:00 음봉전환 ================
# ==============2022-03-22 10:25:00 이전 5분봉 크기 : -1600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 85000.0, 이전5봉 : 1600.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 50318000.0 ######################################################
# ======================= 양봉전환 stick_size :: -64000.0 ================
# ============== 수익률 0.00024870135378565685 =================
# ======================= 양봉전환 stick_size :: -12000.0 ================
# ============== 수익률 0.0002694597332348641 =================
# ======================= 양봉전환 stick_size :: -22000.0 ================
# ============== 수익률 0.0003381220652591438 =================
# ======================= 양봉전환 stick_size :: -38000.0 ================
# ============== 수익률 0.0003988004051875902 =================
# ======================= 양봉전환 stick_size :: -5000.0 ================
# ============== 수익률 0.00040039720360676554 =================
# ======================= 음봉전환 stick_size :: 16000.0 ================
# ==============2022-03-22 10:55:00 음봉전환 ================
# ==============2022-03-22 10:55:00 이전 5분봉 크기 : -28200.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50351000.0 ######################################################
# ======================= 양봉전환 stick_size :: -640000.0 ================
# ============== 수익률 0.0013967994171685684 =================
# ======================= 음봉전환 stick_size :: 221000.0 ================
# ==============2022-03-22 11:05:00 음봉전환 ================
# ==============2022-03-22 11:05:00 이전 5분봉 크기 : -137800.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50975000.0 ######################################################
# ======================= 양봉전환 stick_size :: -120000.0 ================
# ============== 수익률 0.0012243451878982525 =================
# ======================= 음봉전환 stick_size :: 69000.0 ================
# ==============2022-03-22 11:15:00 음봉전환 ================
# ==============2022-03-22 11:15:00 이전 5분봉 크기 : -105600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50867000.0 ######################################################
# ======================= 양봉전환 stick_size :: -107000.0 ================
# ============== 수익률 0.0012786363341500263 =================
# ======================= 양봉전환 stick_size :: -124000.0 ================
# ============== 수익률 0.0014766393381270466 =================
# ======================= 음봉전환 stick_size :: 41000.0 ================
# ==============2022-03-22 11:30:00 음봉전환 ================
# ==============2022-03-22 11:30:00 이전 5분봉 크기 : -12200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 41000.0, 이전5봉 : 12200.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 51025000.0 ######################################################
# ======================= 음봉전환 stick_size :: 150000.0 ================
# ==============2022-03-22 11:35:00 음봉전환 ================
# ==============2022-03-22 11:35:00 이전 5분봉 크기 : -48200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 150000.0, 이전5봉 : 48200.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 51002000.0 ######################################################
# ======================= 양봉전환 stick_size :: -98000.0 ================
# ============== 수익률 0.0014367193776478075 =================
# ======================= 양봉전환 stick_size :: -2000.0 ================
# ============== 수익률 0.0013808314329768726 =================
# ======================= 음봉전환 stick_size :: 1000.0 ================
# ==============2022-03-22 11:50:00 음봉전환 ================
# ==============2022-03-22 11:50:00 이전 5분봉 크기 : -6600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 50965000.0 ######################################################
# ======================= 음봉전환 stick_size :: 38000.0 ================
# ==============2022-03-22 11:55:00 음봉전환 ================
# ==============2022-03-22 11:55:00 이전 5분봉 크기 : 18400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 38000.0, 이전5봉 : 18400.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 50969000.0 ######################################################
# ======================= 양봉전환 stick_size :: -156000.0 ================
# ============== 수익률 0.0014686553460311986 =================
# ======================= 양봉전환 stick_size :: -152000.0 ================
# ============== 수익률 0.0017113687057449696 =================
# ======================= 음봉전환 stick_size :: 80000.0 ================
# ==============2022-03-22 12:10:00 음봉전환 ================
# ==============2022-03-22 12:10:00 이전 5분봉 크기 : -54200.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 51172000.0 ######################################################
# ======================= 양봉전환 stick_size :: -134000.0 ================
# ============== 수익률 0.0017880150298651117 =================
# ======================= 양봉전환 stick_size :: -50000.0 ================
# ============== 수익률 0.00186785495082359 =================
# ======================= 음봉전환 stick_size :: 31000.0 ================
# ==============2022-03-22 12:25:00 음봉전환 ================
# ==============2022-03-22 12:25:00 이전 5분봉 크기 : -82400.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 51270000.0 ######################################################
# ======================= 음봉전환 stick_size :: 66000.0 ================
# ==============2022-03-22 12:35:00 음봉전환 ================
# ==============2022-03-22 12:35:00 이전 5분봉 크기 : -14600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 66000.0, 이전5봉 : 14600.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 51235000.0 ######################################################
# ======================= 양봉전환 stick_size :: -40000.0 ================
# ============== 수익률 0.0017528854646433841 =================
# ======================= 음봉전환 stick_size :: 40000.0 ================
# ==============2022-03-22 12:45:00 음봉전환 ================
# ==============2022-03-22 12:45:00 이전 5분봉 크기 : 1400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 40000.0, 이전5봉 : 1400.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 51198000.0 ######################################################
# ======================= 양봉전환 stick_size :: -118000.0 ================
# ============== 수익률 0.0018886133302727973 =================
# ======================= 양봉전환 stick_size :: -17000.0 ================
# ============== 수익률 0.001887016531853622 =================
# ======================= 양봉전환 stick_size :: -100000.0 ================
# ============== 수익률 0.002048293172189754 =================
# ======================= 양봉전환 stick_size :: -9000.0 ================
# ============== 수익률 0.002062664357962274 =================
# ======================= 양봉전환 stick_size :: -7000.0 ================
# ============== 수익률 0.0020738419468964726 =================
# ======================= 양봉전환 stick_size :: -83000.0 ================
# ============== 수익률 0.0022079730141067104 =================
# ======================= 양봉전환 stick_size :: -13000.0 ================
# ============== 수익률 0.002223940998298406 =================
# ======================= 양봉전환 stick_size :: -660000.0 ================
# ============== 수익률 0.003277827954950319 =================
# ======================= 양봉전환 stick_size :: -154000.0 ================
# ============== 수익률 0.003581219654592536 =================
# ======================= 음봉전환 stick_size :: 33000.0 ================
# ==============2022-03-22 13:35:00 음봉전환 ================
# ==============2022-03-22 13:35:00 이전 5분봉 크기 : -183400.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 52343000.0 ######################################################
# ======================= 음봉전환 stick_size :: 220000.0 ================
# ==============2022-03-22 13:40:00 음봉전환 ================
# ==============2022-03-22 13:40:00 이전 5분봉 크기 : -175400.0 ============
# ###################################################### tic_count : 2, tic : 1, tic_start: 52310000.0 ######################################################
# ======================= 양봉전환 stick_size :: -15000.0 ================
# ============== 수익률 0.003199584832411016 =================
# ======================= 양봉전환 stick_size :: -25000.0 ================
# ============== 수익률 0.003273037559692807 =================
# ======================= 양봉전환 stick_size :: -53000.0 ================
# ============== 수익률 0.003357667875908797 =================
# ======================= 양봉전환 stick_size :: -48000.0 ================
# ============== 수익률 0.0034327174016097637 =================
# ======================= 음봉전환 stick_size :: 86000.0 ================
# ==============2022-03-22 14:05:00 음봉전환 ================
# ==============2022-03-22 14:05:00 이전 5분봉 크기 : 15800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 86000.0, 이전5봉 : 15800.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 52250000.0 ######################################################
# ======================= 음봉전환 stick_size :: 168000.0 ================
# ==============2022-03-22 14:10:00 음봉전환 ================
# ==============2022-03-22 14:10:00 이전 5분봉 크기 : -11000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 168000.0, 이전5봉 : 11000.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 52164000.0 ######################################################
# ======================= 음봉전환 stick_size :: 56000.0 ================
# ==============2022-03-22 14:15:00 음봉전환 ================
# ==============2022-03-22 14:15:00 이전 5분봉 크기 : 25600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 56000.0, 이전5봉 : 25600.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ==================== 구매 tic : 3 ===============
# Buy KRW-BTC, KRW: 9868.6
# ======================== 2022-03-22 14:15:00 시간 매수 완료 : 51940000.0 ===============
# ============================= 2022-03-22 14:15:00 시간 가격 : 51940000.0, 매수평균 금액 : 50453333.333333336 ===============
# ###################################################### tic_count : 0, tic : 0, tic_start: 0 ######################################################
# ======================= 양봉전환 stick_size :: -49000.0 ================
# ============== 수익률 0.003011337209302325 =================
# ======================= 음봉전환 stick_size :: 6000.0 ================
# ==============2022-03-22 14:25:00 음봉전환 ================
# ==============2022-03-22 14:25:00 이전 5분봉 크기 : 42600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 51988000.0 ######################################################
# ======================= 양봉전환 stick_size :: -38000.0 ================
# ============== 수익률 0.0031388808139534846 =================
# ======================= 음봉전환 stick_size :: 33000.0 ================
# ==============2022-03-22 14:35:00 음봉전환 ================
# ==============2022-03-22 14:35:00 이전 5분봉 크기 : 28600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 52053000.0 ######################################################
# ======================= 음봉전환 stick_size :: 28000.0 ================
# ==============2022-03-22 14:40:00 음봉전환 ================
# ==============2022-03-22 14:40:00 이전 5분봉 크기 : 1600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 28000.0, 이전5봉 : 1600.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 52051000.0 ######################################################
# ======================= 음봉전환 stick_size :: 13000.0 ================
# ==============2022-03-22 14:45:00 음봉전환 ================
# ==============2022-03-22 14:45:00 이전 5분봉 크기 : -4000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 13000.0, 이전5봉 : 4000.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 1, tic_start: 52023000.0 ######################################################
# ======================= 양봉전환 stick_size :: -57000.0 ================
# ============== 수익률 0.003166351744186044 =================
# ======================= 양봉전환 stick_size :: -7000.0 ================
# ============== 수익률 0.0031918604651162675 =================
# ======================= 음봉전환 stick_size :: 248000.0 ================
# ==============2022-03-22 15:00:00 음봉전환 ================
# ==============2022-03-22 15:00:00 이전 5분봉 크기 : 2000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 248000.0, 이전5봉 : 2000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 52080000.0 ######################################################
# ======================= 음봉전환 stick_size :: 130000.0 ================
# ==============2022-03-22 15:05:00 음봉전환 ================
# ==============2022-03-22 15:05:00 이전 5분봉 크기 : 45000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 130000.0, 이전5봉 : 45000.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 51832000.0 ######################################################
# ======================= 양봉전환 stick_size :: -30000.0 ================
# ============== 수익률 0.002505087209302314 =================
# ======================= 음봉전환 stick_size :: 64000.0 ================
# ==============2022-03-22 15:15:00 음봉전환 ================
# ==============2022-03-22 15:15:00 이전 5분봉 크기 : 56800.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 51730000.0 ######################################################
# ======================= 음봉전환 stick_size :: 119000.0 ================
# ==============2022-03-22 15:20:00 음봉전환 ================
# ...
# ==============2022-03-22 18:20:00 음봉전환 ================
# ==============2022-03-22 18:20:00 이전 5분봉 크기 : -800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 11000.0, 이전5봉 : 800.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 1, tic_start: 51731000.0 ######################################################
# ======================= 음봉전환 stick_size :: 70000.0 ================
# ==============2022-03-22 18:25:00 음봉전환 ================
# ==============2022-03-22 18:25:00 이전 5분봉 크기 : 16600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 70000.0, 이전5봉 : 16600.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 4, tic : 2, tic_start: 51668000.0 ######################################################
# ======================= 양봉전환 stick_size :: -18000.0 ================
# ============== 수익률 0.002418749999999993 =================
# ======================= 음봉전환 stick_size :: 47000.0 ================
# ==============2022-03-22 18:35:00 음봉전환 ================
# ==============2022-03-22 18:35:00 이전 5분봉 크기 : 27400.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 51686000.0 ######################################################
# ======================= 양봉전환 stick_size :: -40000.0 ================
# ============== 수익률 0.0024207122093023144 =================
# ======================= 양봉전환 stick_size :: -13000.0 ================
# ============== 수익률 0.0024462209302325523 =================
# ======================= 양봉전환 stick_size :: -18000.0 ================
# ============== 수익률 0.002481540697674412 =================
# ======================= 음봉전환 stick_size :: 82000.0 ================
# ==============2022-03-22 18:55:00 음봉전환 ================
# ==============2022-03-22 18:55:00 이전 5분봉 크기 : -8400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 82000.0, 이전5봉 : 8400.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 51718000.0 ######################################################
# ======================= 양봉전환 stick_size :: -37000.0 ================
# ============== 수익률 0.0023873546511627907 =================
# ======================= 양봉전환 stick_size :: -10000.0 ================
# ============== 수익률 0.0024069767441860348 =================
# ======================= 양봉전환 stick_size :: -92000.0 ================
# ============== 수익률 0.0025874999999999917 =================
# ======================= 양봉전환 stick_size :: -75000.0 ================
# ============== 수익률 0.0027346656976744103 =================
# ======================= 양봉전환 stick_size :: -85000.0 ================
# ============== 수익률 0.0029073401162790667 =================
# ======================= 음봉전환 stick_size :: 62000.0 ================
# ==============2022-03-22 19:25:00 음봉전환 ================
# ==============2022-03-22 19:25:00 이전 5분봉 크기 : -59800.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 51935000.0 ######################################################
# ======================= 양봉전환 stick_size :: -162000.0 ================
# ============== 수익률 0.003131031976744184 =================
# ======================= 음봉전환 stick_size :: 96000.0 ================
# ==============2022-03-22 19:35:00 음봉전환 ================
# ==============2022-03-22 19:35:00 이전 5분봉 크기 : -70400.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 52049000.0 ######################################################
# ======================= 양봉전환 stick_size :: -29000.0 ================
# ============== 수익률 0.0030289970930232474 =================
# ======================= 양봉전환 stick_size :: -43000.0 ================
# ============== 수익률 0.003113372093023247 =================
# ======================= 양봉전환 stick_size :: -47000.0 ================
# ============== 수익률 0.003205595930232547 =================
# ======================= 음봉전환 stick_size :: 88000.0 ================
# ==============2022-03-22 19:55:00 음봉전환 ================
# ==============2022-03-22 19:55:00 이전 5분봉 크기 : -37000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 88000.0, 이전5봉 : 37000.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 52087000.0 ######################################################
# ======================= 양봉전환 stick_size :: -7000.0 ================
# ============== 수익률 0.003042732558139527 =================
# ======================= 양봉전환 stick_size :: -140000.0 ================
# ============== 수익률 0.003327252906976742 =================
# ======================= 음봉전환 stick_size :: 4000.0 ================
# ==============2022-03-22 20:10:00 음봉전환 ================
# ==============2022-03-22 20:10:00 이전 5분봉 크기 : -29800.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 52149000.0 ######################################################
# ======================= 음봉전환 stick_size :: 60000.0 ================
# ==============2022-03-22 20:15:00 음봉전환 ================
# ==============2022-03-22 20:15:00 이전 5분봉 크기 : -20400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 60000.0, 이전5봉 : 20400.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 52144000.0 ######################################################
# ======================= 양봉전환 stick_size :: -62000.0 ================
# ============== 수익률 0.003321366279069763 =================
# ======================= 음봉전환 stick_size :: 14000.0 ================
# ==============2022-03-22 20:25:00 음봉전환 ================
# ==============2022-03-22 20:25:00 이전 5분봉 크기 : -29000.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 52146000.0 ######################################################
# ======================= 음봉전환 stick_size :: 79000.0 ================
# ==============2022-03-22 20:30:00 음봉전환 ================
# ==============2022-03-22 20:30:00 이전 5분봉 크기 : -24800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 79000.0, 이전5봉 : 24800.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 52131000.0 ######################################################
# ======================= 음봉전환 stick_size :: 37000.0 ================
# ==============2022-03-22 20:35:00 음봉전환 ================
# ==============2022-03-22 20:35:00 이전 5분봉 크기 : 19000.0 ============
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 2, tic_start: 52015000.0 ######################################################
# ======================= 양봉전환 stick_size :: -83000.0 ================
# ============== 수익률 0.003231104651162785 =================
# ======================= 양봉전환 stick_size :: -37000.0 ================
# ============== 수익률 0.003303706395348826 =================
# ======================= 양봉전환 stick_size :: -8000.0 ================
# ============== 수익률 0.0033194040697674416 =================
# ======================= 양봉전환 stick_size :: -65000.0 ================
# ============== 수익률 0.003446947674418602 =================
# ======================= 음봉전환 stick_size :: 10000.0 ================
# ==============2022-03-22 21:00:00 음봉전환 ================
# ==============2022-03-22 21:00:00 이전 5분봉 크기 : -31200.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 52210000.0 ######################################################
# ======================= 양봉전환 stick_size :: -15000.0 ================
# ============== 수익률 0.003456758720930224 =================
# ======================= 음봉전환 stick_size :: 42000.0 ================
# ==============2022-03-22 21:10:00 음봉전환 ================
# ==============2022-03-22 21:10:00 이전 5분봉 크기 : -23000.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 52215000.0 ######################################################
# ======================= 음봉전환 stick_size :: 17000.0 ================
# ==============2022-03-22 21:15:00 음봉전환 ================
# ==============2022-03-22 21:15:00 이전 5분봉 크기 : -7200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 17000.0, 이전5봉 : 7200.0 ==========
# ###################################################### tic_count : 2, tic : 0, tic_start: 52173000.0 ######################################################
# ======================= 양봉전환 stick_size :: -29000.0 ================
# ============== 수익률 0.003395930232558126 =================
# ======================= 양봉전환 stick_size :: -22000.0 ================
# ============== 수익률 0.003472456395348825 =================
# ======================= 음봉전환 stick_size :: 11000.0 ================
# ==============2022-03-22 21:30:00 음봉전환 ================
# ==============2022-03-22 21:30:00 이전 5분봉 크기 : -1400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 11000.0, 이전5봉 : 1400.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 52223000.0 ######################################################
# ======================= 음봉전환 stick_size :: 35000.0 ================
# ==============2022-03-22 21:35:00 음봉전환 ================
# ==============2022-03-22 21:35:00 이전 5분봉 크기 : 3800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 35000.0, 이전5봉 : 3800.0 ==========
# ###################################################### tic_count : 2, tic : 2, tic_start: 52212000.0 ######################################################
# ======================= 양봉전환 stick_size :: -24000.0 ================
# ============== 수익률 0.0033782703488372035 =================
# ======================= 양봉전환 stick_size :: -21000.0 ================
# ============== 수익률 0.0034175145348837206 =================
# ======================= 양봉전환 stick_size :: -18000.0 ================
# ============== 수익률 0.0034528343023255805 =================
# ======================= 양봉전환 stick_size :: -24000.0 ================
# ============== 수익률 0.0035058139534883633 =================
# ======================= 양봉전환 stick_size :: -28000.0 ================
# ============== 수익률 0.0035587936046511605 =================
# ======================= 음봉전환 stick_size :: 67000.0 ================
# ==============2022-03-22 22:10:00 음봉전환 ================
# ==============2022-03-22 22:10:00 이전 5분봉 크기 : -18200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 67000.0, 이전5봉 : 18200.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 52267000.0 ######################################################
# ======================= 양봉전환 stick_size :: -55000.0 ================
# ============== 수익률 0.003519549418604643 =================
# ======================= 음봉전환 stick_size :: 4000.0 ================
# ==============2022-03-22 22:20:00 음봉전환 ================
# ==============2022-03-22 22:20:00 이전 5분봉 크기 : -11600.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 52247000.0 ######################################################
# ======================= 음봉전환 stick_size :: 59000.0 ================
# ==============2022-03-22 22:25:00 음봉전환 ================
# ==============2022-03-22 22:25:00 이전 5분봉 크기 : -7200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 59000.0, 이전5봉 : 7200.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 52243000.0 ######################################################
# ======================= 양봉전환 stick_size :: -33000.0 ================
# ============== 수익률 0.00346656976744186 =================
# ======================= 양봉전환 stick_size :: -40000.0 ================
# ============== 수익률 0.003545058139534881 =================
# ======================= 음봉전환 stick_size :: 3000.0 ================
# ==============2022-03-22 22:40:00 음봉전환 ================
# ==============2022-03-22 22:40:00 이전 5분봉 크기 : -13000.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 52260000.0 ######################################################
# ======================= 음봉전환 stick_size :: 132000.0 ================
# ==============2022-03-22 22:45:00 음봉전환 ================
# ==============2022-03-22 22:45:00 이전 5분봉 크기 : -1400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 132000.0, 이전5봉 : 1400.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 52257000.0 ######################################################
# ======================= 음봉전환 stick_size :: 147000.0 ================
# ==============2022-03-22 22:50:00 음봉전환 ================
# ==============2022-03-22 22:50:00 이전 5분봉 크기 : 24200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 147000.0, 이전5봉 : 24200.0 ==========
# ======================== 누적 tic_count 가 2초과인 경우의 tic 계산 ====================
# ###################################################### tic_count : 3, tic : 2, tic_start: 51982000.0 ######################################################
# ======================= 양봉전환 stick_size :: -121000.0 ================
# ============== 수익률 0.0032369912790697637 =================
# ======================= 양봉전환 stick_size :: -65000.0 ================
# ============== 수익률 0.003364534883720924 =================
# ======================= 음봉전환 stick_size :: 23000.0 ================
# ==============2022-03-22 23:05:00 음봉전환 ================
# ==============2022-03-22 23:05:00 이전 5분봉 크기 : 19200.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 52168000.0 ######################################################
# ======================= 양봉전환 stick_size :: -15000.0 ================
# ============== 수익률 0.0033370639534883646 =================
# ======================= 양봉전환 stick_size :: -19000.0 ================
# ============== 수익률 0.003368459302325581 =================
# ======================= 양봉전환 stick_size :: -5000.0 ================
# ============== 수익률 0.0033606104651162662 =================
# ======================= 음봉전환 stick_size :: 36000.0 ================
# ==============2022-03-22 23:25:00 음봉전환 ================
# ==============2022-03-22 23:25:00 이전 5분봉 크기 : -16200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 36000.0, 이전5봉 : 16200.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 52166000.0 ######################################################
# ======================= 양봉전환 stick_size :: -172000.0 ================
# ============== 수익률 0.0036215843023255797 =================
# ======================= 음봉전환 stick_size :: 66000.0 ================
# ==============2022-03-22 23:35:00 음봉전환 ================
# ==============2022-03-22 23:35:00 이전 5분봉 크기 : -35000.0 ============
# ###################################################### tic_count : 1, tic : 0, tic_start: 52299000.0 ######################################################
# ======================= 음봉전환 stick_size :: 160000.0 ================
# ==============2022-03-22 23:40:00 음봉전환 ================
# ==============2022-03-22 23:40:00 이전 5분봉 크기 : -18800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 160000.0, 이전5봉 : 18800.0 ==========
# ###################################################### tic_count : 2, tic : 1, tic_start: 52233000.0 ######################################################
# ======================= 양봉전환 stick_size :: -18000.0 ================
# ============== 수익률 0.0032114825581395262 =================
# ======================= 음봉전환 stick_size :: 65000.0 ================
# ==============2022-03-22 23:50:00 음봉전환 ================
# ==============2022-03-22 23:50:00 이전 5분봉 크기 : 14400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 65000.0, 이전5봉 : 14400.0 ==========
# ###################################################### tic_count : 1, tic : 1, tic_start: 52090000.0 ######################################################
# 0.1548795599999954 % !!!!!
# 0.1548795599999954

# %%
# 0.1 => 0.03 %
# 0.05 => 0.019 %
# 한달 0.05 => -5.4
# 한달 0.1 => -4.11
# 한달 0.5 => -1.75
# 고친 후 한달 0.05 => 0.21074215800003146
