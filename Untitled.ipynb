# %%
import pandas as pd
import pyupbit

# %%
import time

# %%
df2 = pyupbit.get_ohlcv('KRW-BTC', 'minute5', to='20220224 00:00:00', count=8928)

# %%
# df2.head()

# %%
df2_reset = df2.reset_index()
df2_reset.columns = ['timestamp', 'open', 'high', 'low', 'close', 'volume', 'value']

# %%
# df = pd.read_csv('./data/data.csv')

# %%
# df.head()

# %%
df2_reset.head()
# Out:
#             timestamp        open        high         low       close  \
# 0 2022-01-23 21:55:00  43997000.0  44053000.0  43933000.0  44041000.0
# 1 2022-01-23 22:00:00  44041000.0  44049000.0  43975000.0  44000000.0
# 2 2022-01-23 22:05:00  43999000.0  44000000.0  43929000.0  43950000.0
# 3 2022-01-23 22:10:00  43950000.0  44000000.0  43940000.0  43990000.0
# 4 2022-01-23 22:15:00  43993000.0  43999000.0  43952000.0  43994000.0
#
#       volume         value
# 0  13.177692  5.801811e+08
# 1   5.874105  2.585371e+08
# 2   5.865223  2.578396e+08
# 3  17.719987  7.792825e+08
# 4  10.134248  4.457752e+08

# %%
from upbit_backtest import backtesting

# %%
backtesting(df2_reset)
# Out:
# ======================= 양봉전환 stick_size :: -44000.0 ================
# ======================= tic ::::::: 0 =====================
# ======================= 음봉전환 stick_size :: 41000.0 ================
# ==============2022-01-23 22:00:00 음봉전환 ================
# ==============2022-01-23 22:00:00 이전 5분봉 크기 : -45000.0 ============
# ======================= 음봉전환 stick_size :: 49000.0 ================
# ==============2022-01-23 22:05:00 음봉전환 ================
# ==============2022-01-23 22:05:00 이전 5분봉 크기 : -16200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 49000.0, 이전5봉 : 16200.0 ==========
# ================= 누적 tic_count : 2
# ==================== 구매 tic : 3 ===============
# Buy KRW-BTC, KRW: 10108.5
# ======================== 2022-01-23 22:05:00 시간 매수 완료 : 43950000.0 ===============
# ======================= 양봉전환 stick_size :: -40000.0 ================
# ======================= tic ::::::: 3 =====================
# ============== 수익률 0.09101251422070535 =================
# ======================= 양봉전환 stick_size :: -1000.0 ================
# ======================= tic ::::::: 3 =====================
# ============== 수익률 0.10011376564277588 =================
# ======================= 양봉전환 stick_size :: -52000.0 ================
# ======================= tic ::::::: 3 =====================
# ============== 수익률 0.21843003412969283 =================
# ======================= 양봉전환 stick_size :: -4000.0 ================
# ======================= tic ::::::: 3 =====================
# ============== 수익률 0.22753128555176336 =================
# ======================= 음봉전환 stick_size :: 27000.0 ================
# ==============2022-01-23 22:30:00 음봉전환 ================
# ==============2022-01-23 22:30:00 이전 5분봉 크기 : -9600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 27000.0, 이전5봉 : 9600.0 ==========
# ==================== 구매 tic : 5 ===============
# Buy KRW-BTC, KRW: 10125.52
# ======================== 2022-01-23 22:30:00 시간 매수 완료 : 44024000.0 ===============
# ======================= 음봉전환 stick_size :: 14000.0 ================
# ==============2022-01-23 22:40:00 음봉전환 ================
# ==============2022-01-23 22:40:00 이전 5분봉 크기 : -6000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 14000.0, 이전5봉 : 6000.0 ==========
# ==================== 구매 tic : 7 ===============
# Buy KRW-BTC, KRW: 10122.300000000001
# ======================== 2022-01-23 22:40:00 시간 매수 완료 : 44010000.0 ===============
# ======================= 양봉전환 stick_size :: -55000.0 ================
# ======================= tic ::::::: 7 =====================
# ============== 수익률 0.13941083767729986 =================
# ======================= 양봉전환 stick_size :: -50000.0 ================
# ======================= tic ::::::: 7 =====================
# ============== 수익률 0.2507879742999208 =================
# ======================= 양봉전환 stick_size :: -85000.0 ================
# ======================= tic ::::::: 7 =====================
# ============== 수익률 0.4462662140865616 =================
# ======================= 음봉전환 stick_size :: 46000.0 ================
# ==============2022-01-23 23:00:00 음봉전환 ================
# ==============2022-01-23 23:00:00 이전 5분봉 크기 : -35200.0 ============
# ==================== 구매 tic : 7 ===============
# Buy KRW-BTC, KRW: 10154.73
# ======================== 2022-01-23 23:00:00 시간 매수 완료 : 44151000.0 ===============
# ======================= 음봉전환 stick_size :: 131000.0 ================
# ==============2022-01-23 23:05:00 음봉전환 ================
# ==============2022-01-23 23:05:00 이전 5분봉 크기 : -26000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 131000.0, 이전5봉 : 26000.0 ==========
# ==================== 구매 tic : 9 ===============
# Buy KRW-BTC, KRW: 10124.6
# ======================== 2022-01-23 23:05:00 시간 매수 완료 : 44020000.0 ===============
# ======================= 음봉전환 stick_size :: 30000.0 ================
# ==============2022-01-23 23:10:00 음봉전환 ================
# ==============2022-01-23 23:10:00 이전 5분봉 크기 : -2600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 30000.0, 이전5봉 : 2600.0 ==========
# ==================== 구매 tic : 11 ===============
# Buy KRW-BTC, KRW: 10118.85
# ======================== 2022-01-23 23:10:00 시간 매수 완료 : 43995000.0 ===============
# ======================= 음봉전환 stick_size :: 182000.0 ================
# ==============2022-01-23 23:15:00 음봉전환 ================
# ==============2022-01-23 23:15:00 이전 5분봉 크기 : 14400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 182000.0, 이전5봉 : 14400.0 ==========
# ==================== 구매 tic : 13 ===============
# Buy KRW-BTC, KRW: 10076.07
# ======================== 2022-01-23 23:15:00 시간 매수 완료 : 43809000.0 ===============
# ======================= 음봉전환 stick_size :: 78000.0 ================
# ==============2022-01-23 23:20:00 음봉전환 ================
# ==============2022-01-23 23:20:00 이전 5분봉 크기 : 60800.0 ============
# ==================== 구매 tic : 13 ===============
# Buy KRW-BTC, KRW: 10057.9
# ======================== 2022-01-23 23:20:00 시간 매수 완료 : 43730000.0 ===============
# ======================= 양봉전환 stick_size :: -99000.0 ================
# ======================= tic ::::::: 13 =====================
# ============== 수익률 -0.28690121101315635 =================
# ======================= 음봉전환 stick_size :: 22000.0 ================
# ==============2022-01-23 23:30:00 음봉전환 ================
# ==============2022-01-23 23:30:00 이전 5분봉 크기 : 64400.0 ============
# ==================== 구매 tic : 13 ===============
# Buy KRW-BTC, KRW: 10071.7
# ======================== 2022-01-23 23:30:00 시간 매수 완료 : 43790000.0 ===============
# ======================= 음봉전환 stick_size :: 120000.0 ================
# ==============2022-01-23 23:35:00 음봉전환 ================
# ==============2022-01-23 23:35:00 이전 5분봉 크기 : 42600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 120000.0, 이전5봉 : 42600.0 ==========
# ==================== 구매 tic : 15 ===============
# Buy KRW-BTC, KRW: 10044.33
# ======================== 2022-01-23 23:35:00 시간 매수 완료 : 43671000.0 ===============
# ======================= 음봉전환 stick_size :: 95000.0 ================
# ==============2022-01-23 23:40:00 음봉전환 ================
# ==============2022-01-23 23:40:00 이전 5분봉 크기 : 60600.0 ============
# ==================== 구매 tic : 15 ===============
# Buy KRW-BTC, KRW: 10022.48
# ======================== 2022-01-23 23:40:00 시간 매수 완료 : 43576000.0 ===============
# ======================= 음봉전환 stick_size :: 233000.0 ================
# ==============2022-01-23 23:45:00 음봉전환 ================
# ==============2022-01-23 23:45:00 이전 5분봉 크기 : 43200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 233000.0, 이전5봉 : 43200.0 ==========
# ==================== 구매 tic : 17 ===============
# Buy KRW-BTC, KRW: 9969.58
# ======================== 2022-01-23 23:45:00 시간 매수 완료 : 43346000.0 ===============
# ======================= 음봉전환 stick_size :: 6000.0 ================
# ==============2022-01-23 23:50:00 음봉전환 ================
# ==============2022-01-23 23:50:00 이전 5분봉 크기 : 74200.0 ============
# ==================== 구매 tic : 17 ===============
# Buy KRW-BTC, KRW: 9978.09
# ======================== 2022-01-23 23:50:00 시간 매수 완료 : 43383000.0 ===============
# ======================= 양봉전환 stick_size :: -9000.0 ================
# ======================= tic ::::::: 17 =====================
# ============== 수익률 -0.9433581231176984 =================
# ======================= 음봉전환 stick_size :: 75000.0 ================
# ==============2022-01-24 00:00:00 음봉전환 ================
# ==============2022-01-24 00:00:00 이전 5분봉 크기 : 89000.0 ============
# ==================== 구매 tic : 17 ===============
# Buy KRW-BTC, KRW: 9961.300000000001
# ======================== 2022-01-24 00:00:00 시간 매수 완료 : 43310000.0 ===============
# ======================= 음봉전환 stick_size :: 12000.0 ================
# ==============2022-01-24 00:05:00 음봉전환 ================
# ==============2022-01-24 00:05:00 이전 5분봉 크기 : 80000.0 ============
# ==================== 구매 tic : 17 ===============
# Buy KRW-BTC, KRW: 9958.54
# ======================== 2022-01-24 00:05:00 시간 매수 완료 : 43298000.0 ===============
# ======================= 음봉전환 stick_size :: 25000.0 ================
# ==============2022-01-24 00:10:00 음봉전환 ================
# ==============2022-01-24 00:10:00 이전 5분봉 크기 : 63400.0 ============
# ==================== 구매 tic : 17 ===============
# Buy KRW-BTC, KRW: 9952.56
# ======================== 2022-01-24 00:10:00 시간 매수 완료 : 43272000.0 ===============
# ======================= 양봉전환 stick_size :: -11000.0 ================
# ======================= tic ::::::: 17 =====================
# ============== 수익률 -1.014535237046589 =================
# ======================= 양봉전환 stick_size :: -79000.0 ================
# ======================= tic ::::::: 17 =====================
# ============== 수익률 -0.820064775822712 =================
# ======================= 음봉전환 stick_size :: 16000.0 ================
# ==============2022-01-24 00:25:00 음봉전환 ================
# ==============2022-01-24 00:25:00 이전 5분봉 크기 : 4400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 16000.0, 이전5봉 : 4400.0 ==========
# ==================== 구매 tic : 19 ===============
# Buy KRW-BTC, KRW: 9965.67
# ======================== 2022-01-24 00:25:00 시간 매수 완료 : 43329000.0 ===============
# ======================= 음봉전환 stick_size :: 61000.0 ================
# ==============2022-01-24 00:30:00 음봉전환 ================
# ==============2022-01-24 00:30:00 이전 5분봉 크기 : -7400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 61000.0, 이전5봉 : 7400.0 ==========
# ==================== 구매 tic : 21 ===============
# Buy KRW-BTC, KRW: 9951.64
# ======================== 2022-01-24 00:30:00 시간 매수 완료 : 43268000.0 ===============
# ======================= 음봉전환 stick_size :: 49000.0 ================
# ==============2022-01-24 00:35:00 음봉전환 ================
# ==============2022-01-24 00:35:00 이전 5분봉 크기 : 2400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 49000.0, 이전5봉 : 2400.0 ==========
# ==================== 구매 tic : 23 ===============
# Buy KRW-BTC, KRW: 9939.91
# ======================== 2022-01-24 00:35:00 시간 매수 완료 : 43217000.0 ===============
# ======================= 음봉전환 stick_size :: 87000.0 ================
# ==============2022-01-24 00:40:00 음봉전환 ================
# ==============2022-01-24 00:40:00 이전 5분봉 크기 : 7200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 87000.0, 이전5봉 : 7200.0 ==========
# ==================== 구매 tic : 25 ===============
# Buy KRW-BTC, KRW: 9919.9
# ======================== 2022-01-24 00:40:00 시간 매수 완료 : 43130000.0 ===============
# ======================= 음봉전환 stick_size :: 45000.0 ================
# ==============2022-01-24 00:45:00 음봉전환 ================
# ==============2022-01-24 00:45:00 이전 5분봉 크기 : 26800.0 ============
# ==================== 구매 tic : 25 ===============
# Buy KRW-BTC, KRW: 9908.4
# ======================== 2022-01-24 00:45:00 시간 매수 완료 : 43080000.0 ===============
# ======================= 양봉전환 stick_size :: -76000.0 ================
# ======================= tic ::::::: 25 =====================
# ============== 수익률 -0.9922882715961296 =================
# ======================= 양봉전환 stick_size :: -164000.0 ================
# ======================= tic ::::::: 25 =====================
# ============== 수익률 -0.6160424489189067 =================
# ======================= 음봉전환 stick_size :: 1000.0 ================
# ==============2022-01-24 01:00:00 음봉전환 ================
# ==============2022-01-24 01:00:00 이전 5분봉 크기 : -11800.0 ============
# ==================== 구매 tic : 25 ===============
# Buy KRW-BTC, KRW: 9963.37
# ======================== 2022-01-24 01:00:00 시간 매수 완료 : 43319000.0 ===============
# ======================= 양봉전환 stick_size :: -70000.0 ================
# ======================= tic ::::::: 25 =====================
# ============== 수익률 -0.4297584799066522 =================
# ======================= 음봉전환 stick_size :: 18000.0 ================
# ==============2022-01-24 01:10:00 음봉전환 ================
# ==============2022-01-24 01:10:00 이전 5분봉 크기 : -52800.0 ============
# ==================== 구매 tic : 25 ===============
# Buy KRW-BTC, KRW: 9975.33
# ======================== 2022-01-24 01:10:00 시간 매수 완료 : 43371000.0 ===============
# ======================= 양봉전환 stick_size :: -75000.0 ================
# ======================= tic ::::::: 25 =====================
# ============== 수익률 -0.2785292934776057 =================
# ======================= 음봉전환 stick_size :: 53000.0 ================
# ==============2022-01-24 01:20:00 음봉전환 ================
# ==============2022-01-24 01:20:00 이전 5분봉 크기 : -58000.0 ============
# ==================== 구매 tic : 25 ===============
# Buy KRW-BTC, KRW: 9981.31
# ======================== 2022-01-24 01:20:00 시간 매수 완료 : 43397000.0 ===============
# ======================= 음봉전환 stick_size :: 112000.0 ================
# ==============2022-01-24 01:25:00 음봉전환 ================
# ==============2022-01-24 01:25:00 이전 5분봉 크기 : -14600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 112000.0, 이전5봉 : 14600.0 ==========
# ==================== 구매 tic : 27 ===============
# Buy KRW-BTC, KRW: 9955.550000000001
# ======================== 2022-01-24 01:25:00 시간 매수 완료 : 43285000.0 ===============
# ======================= 양봉전환 stick_size :: -9000.0 ================
# ======================= tic ::::::: 27 =====================
# ============== 수익률 -0.5860951878838248 =================
# ======================= 음봉전환 stick_size :: 14000.0 ================
# ==============2022-01-24 01:35:00 음봉전환 ================
# ==============2022-01-24 01:35:00 이전 5분봉 크기 : 19800.0 ============
# ==================== 구매 tic : 27 ===============
# Buy KRW-BTC, KRW: 9954.4
# ======================== 2022-01-24 01:35:00 시간 매수 완료 : 43280000.0 ===============
# ======================= 양봉전환 stick_size :: -11000.0 ================
# ======================= tic ::::::: 27 =====================
# ============== 수익률 -0.5693407572894112 =================
# ======================= 양봉전환 stick_size :: -1000.0 ================
# ======================= tic ::::::: 27 =====================
# ============== 수익률 -0.5670439598201287 =================
# ======================= 양봉전환 stick_size :: -9000.0 ================
# ======================= tic ::::::: 27 =====================
# ============== 수익률 -0.5693407572894112 =================
# ======================= 양봉전환 stick_size :: -9000.0 ================
# ======================= tic ::::::: 27 =====================
# ============== 수익률 -0.5762311496972589 =================
# ======================= 양봉전환 stick_size :: -4000.0 ================
# ======================= tic ::::::: 27 =====================
# ============== 수익률 -0.5670439598201287 =================
# ======================= 양봉전환 stick_size :: -56000.0 ================
# ======================= tic ::::::: 27 =====================
# ============== 수익률 -0.4430168964788713 =================
# ======================= 양봉전환 stick_size :: -18000.0 ================
# ======================= tic ::::::: 27 =====================
# ============== 수익률 -0.40167454203178554 =================
# ======================= 음봉전환 stick_size :: 79000.0 ================
# ==============2022-01-24 02:15:00 음봉전환 ================
# ==============2022-01-24 02:15:00 이전 5분봉 크기 : -19200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 79000.0, 이전5봉 : 19200.0 ==========
# ==================== 구매 tic : 29 ===============
# ======================= 양봉전환 stick_size :: -20000.0 ================
# ======================= tic ::::::: 29 =====================
# ============== 수익률 -0.3718161749311125 =================
# ======================= 양봉전환 stick_size :: -19000.0 ================
# ======================= tic ::::::: 29 =====================
# ============== 수익률 -0.32817702301474416 =================
# ======================= 양봉전환 stick_size :: -6000.0 ================
# ======================= tic ::::::: 29 =====================
# ============== 수익률 -0.32817702301474416 =================
# ======================= 양봉전환 stick_size :: -4000.0 ================
# ======================= tic ::::::: 29 =====================
# ============== 수익률 -0.31898983313761403 =================
# ======================= 음봉전환 stick_size :: 1000.0 ================
# ==============2022-01-24 02:40:00 음봉전환 ================
# ==============2022-01-24 02:40:00 이전 5분봉 크기 : 6000.0 ============
# ================= 누적 tic_count : 2
# ==================== 구매 tic : 29 ===============
# Buy KRW-BTC, KRW: 9981.77
# ======================== 2022-01-24 02:40:00 시간 매수 완료 : 43399000.0 ===============
# ======================= 양봉전환 stick_size :: -1000.0 ================
# ======================= tic ::::::: 29 =====================
# ============== 수익률 -0.307126874877646 =================
# ======================= 음봉전환 stick_size :: 11000.0 ================
# ==============2022-01-24 02:50:00 음봉전환 ================
# ==============2022-01-24 02:50:00 이전 5분봉 크기 : -5800.0 ============
# ==================== 구매 tic : 29 ===============
# Buy KRW-BTC, KRW: 9979.470000000001
# ======================== 2022-01-24 02:50:00 시간 매수 완료 : 43389000.0 ===============
# ======================= 음봉전환 stick_size :: 36000.0 ================
# ==============2022-01-24 02:55:00 음봉전환 ================
# ==============2022-01-24 02:55:00 이전 5분봉 크기 : 200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 36000.0, 이전5봉 : 200.0 ==========
# ==================== 구매 tic : 31 ===============
# Buy KRW-BTC, KRW: 9971.19
# ======================== 2022-01-24 02:55:00 시간 매수 완료 : 43353000.0 ===============
# ======================= 양봉전환 stick_size :: -2000.0 ================
# ======================= tic ::::::: 31 =====================
# ============== 수익률 -0.38481894415248624 =================
# ======================= 음봉전환 stick_size :: 28000.0 ================
# ==============2022-01-24 03:05:00 음봉전환 ================
# ==============2022-01-24 03:05:00 이전 5분봉 크기 : 9000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 28000.0, 이전5봉 : 9000.0 ==========
# ==================== 구매 tic : 33 ===============
# Buy KRW-BTC, KRW: 9965.210000000001
# ======================== 2022-01-24 03:05:00 시간 매수 완료 : 43327000.0 ===============
# ======================= 양봉전환 stick_size :: -22000.0 ================
# ======================= tic ::::::: 33 =====================
# ============== 수익률 -0.39518061952735206 =================
# ======================= 음봉전환 stick_size :: 5000.0 ================
# ==============2022-01-24 03:15:00 음봉전환 ================
# ==============2022-01-24 03:15:00 이전 5분봉 크기 : 10200.0 ============
# ==================== 구매 tic : 33 ===============
# Buy KRW-BTC, KRW: 9960.61
# ======================== 2022-01-24 03:15:00 시간 매수 완료 : 43307000.0 ===============
# ======================= 음봉전환 stick_size :: 69000.0 ================
# ==============2022-01-24 03:20:00 음봉전환 ================
# ==============2022-01-24 03:20:00 이전 5분봉 크기 : 9000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 69000.0, 이전5봉 : 9000.0 ==========
# ==================== 구매 tic : 35 ===============
# Buy KRW-BTC, KRW: 9933.24
# ======================== 2022-01-24 03:20:00 시간 매수 완료 : 43188000.0 ===============
# ======================= 음봉전환 stick_size :: 8000.0 ================
# ==============2022-01-24 03:25:00 음봉전환 ================
# ==============2022-01-24 03:25:00 이전 5분봉 크기 : 15600.0 ============
# ==================== 구매 tic : 35 ===============
# Buy KRW-BTC, KRW: 9930.25
# ======================== 2022-01-24 03:25:00 시간 매수 완료 : 43175000.0 ===============
# ======================= 양봉전환 stick_size :: -26000.0 ================
# ======================= tic ::::::: 35 =====================
# ============== 수익률 -0.6630670404257258 =================
# ======================= 음봉전환 stick_size :: 10000.0 ================
# ==============2022-01-24 03:35:00 음봉전환 ================
# ==============2022-01-24 03:35:00 이전 5분봉 크기 : 6800.0 ============
# ==================== 구매 tic : 35 ===============
# Buy KRW-BTC, KRW: 9917.6
# ======================== 2022-01-24 03:35:00 시간 매수 완료 : 43120000.0 ===============
# ======================= 음봉전환 stick_size :: 30000.0 ================
# ==============2022-01-24 03:40:00 음봉전환 ================
# ==============2022-01-24 03:40:00 이전 5분봉 크기 : 13200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 30000.0, 이전5봉 : 13200.0 ==========
# ==================== 구매 tic : 37 ===============
# Buy KRW-BTC, KRW: 9910.7
# ======================== 2022-01-24 03:40:00 시간 매수 완료 : 43090000.0 ===============
# ======================= 음봉전환 stick_size :: 85000.0 ================
# ==============2022-01-24 03:45:00 음봉전환 ================
# ==============2022-01-24 03:45:00 이전 5분봉 크기 : 18200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 85000.0, 이전5봉 : 18200.0 ==========
# ==================== 구매 tic : 39 ===============
# Buy KRW-BTC, KRW: 9890.23
# ======================== 2022-01-24 03:45:00 시간 매수 완료 : 43001000.0 ===============
# ======================= 음봉전환 stick_size :: 47000.0 ================
# ==============2022-01-24 03:50:00 음봉전환 ================
# ==============2022-01-24 03:50:00 이전 5분봉 크기 : 21400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 47000.0, 이전5봉 : 21400.0 ==========
# ==================== 구매 tic : 41 ===============
# Buy KRW-BTC, KRW: 9879.42
# ======================== 2022-01-24 03:50:00 시간 매수 완료 : 42954000.0 ===============
# ======================= 음봉전환 stick_size :: 4000.0 ================
# ==============2022-01-24 03:55:00 음봉전환 ================
# ==============2022-01-24 03:55:00 이전 5분봉 크기 : 29200.0 ============
# ==================== 구매 tic : 41 ===============
# Buy KRW-BTC, KRW: 9878.960000000001
# ======================== 2022-01-24 03:55:00 시간 매수 완료 : 42952000.0 ===============
# ======================= 음봉전환 stick_size :: 31000.0 ================
# ==============2022-01-24 04:05:00 음봉전환 ================
# ==============2022-01-24 04:05:00 이전 5분봉 크기 : 33200.0 ============
# ==================== 구매 tic : 41 ===============
# Buy KRW-BTC, KRW: 9871.6
# ======================== 2022-01-24 04:05:00 시간 매수 완료 : 42920000.0 ===============
# ======================= 음봉전환 stick_size :: 11000.0 ================
# ==============2022-01-24 04:10:00 음봉전환 ================
# ==============2022-01-24 04:10:00 이전 5분봉 크기 : 33400.0 ============
# ==================== 구매 tic : 41 ===============
# Buy KRW-BTC, KRW: 9869.07
# ======================== 2022-01-24 04:10:00 시간 매수 완료 : 42909000.0 ===============
# ======================= 양봉전환 stick_size :: -39000.0 ================
# ======================= tic ::::::: 41 =====================
# ============== 수익률 -1.0468897151365735 =================
# ======================= 양봉전환 stick_size :: -41000.0 ================
# ======================= tic ::::::: 41 =====================
# ============== 수익률 -0.9547288598838367 =================
# ======================= 양봉전환 stick_size :: -176000.0 ================
# ======================= tic ::::::: 41 =====================
# ============== 수익률 -0.6321658664992582 =================
# ======================= 양봉전환 stick_size :: -40000.0 ================
# ======================= tic ::::::: 41 =====================
# ============== 수익률 -0.5446130540091583 =================
# ======================= 음봉전환 stick_size :: 335000.0 ================
# ==============2022-01-24 04:35:00 음봉전환 ================
# ==============2022-01-24 04:35:00 이전 5분봉 크기 : -57000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 335000.0, 이전5봉 : 57000.0 ==========
# ==================== 구매 tic : 43 ===============
# Buy KRW-BTC, KRW: 9850.9
# ======================== 2022-01-24 04:35:00 시간 매수 완료 : 42830000.0 ===============
# ======================= 음봉전환 stick_size :: 58000.0 ================
# ==============2022-01-24 04:40:00 음봉전환 ================
# ==============2022-01-24 04:40:00 이전 5분봉 크기 : 7800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 58000.0, 이전5봉 : 7800.0 ==========
# ==================== 구매 tic : 45 ===============
# ======================= 양봉전환 stick_size :: -179000.0 ================
# ======================= tic ::::::: 45 =====================
# ============== 수익률 -1.0242702755878157 =================
# ======================= 음봉전환 stick_size :: 155000.0 ================
# ==============2022-01-24 04:50:00 음봉전환 ================
# ==============2022-01-24 04:50:00 이전 5분봉 크기 : -400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 155000.0, 이전5봉 : 400.0 ==========
# ================= 누적 tic_count : 2
# ==================== 구매 tic : 48 ===============
# Buy KRW-BTC, KRW: 9841.470000000001
# ======================== 2022-01-24 04:50:00 시간 매수 완료 : 42789000.0 ===============
# ======================= 양봉전환 stick_size :: -122000.0 ================
# ======================= tic ::::::: 48 =====================
# ============== 수익률 -1.0700911339541037 =================
# ======================= 양봉전환 stick_size :: -25000.0 ================
# ======================= tic ::::::: 48 =====================
# ============== 수익률 -1.0470359233118187 =================
# ======================= 양봉전환 stick_size :: -121000.0 ================
# ======================= tic ::::::: 48 =====================
# ============== 수익률 -0.6389586949433702 =================
# ======================= 양봉전환 stick_size :: -314000.0 ================
# ======================= tic ::::::: 48 =====================
# ============== 수익률 0.02272585049021577 =================
# ======================= 음봉전환 stick_size :: 126000.0 ================
# ==============2022-01-24 05:15:00 음봉전환 ================
# ==============2022-01-24 05:15:00 이전 5분봉 크기 : -85400.0 ============
# ==================== 구매 tic : 48 ===============
# ======================= 양봉전환 stick_size :: -80000.0 ================
# ======================= tic ::::::: 48 =====================
# ============== 수익률 -0.1893820874188083 =================
# ======================= 음봉전환 stick_size :: 123000.0 ================
# ==============2022-01-24 05:25:00 음봉전환 ================
# ==============2022-01-24 05:25:00 이전 5분봉 크기 : -82800.0 ============
# ================= 누적 tic_count : 2
# ==================== 구매 tic : 49 ===============
# Buy KRW-BTC, KRW: 9932.550000000001
# ======================== 2022-01-24 05:25:00 시간 매수 완료 : 43185000.0 ===============
# ======================= 양봉전환 stick_size :: -19000.0 ================
# ======================= tic ::::::: 49 =====================
# ============== 수익률 -0.3821654684784864 =================
# ======================= 양봉전환 stick_size :: -75000.0 ================
# ======================= tic ::::::: 49 =====================
# ============== 수익률 -0.20923385127026234 =================
# ======================= 음봉전환 stick_size :: 18000.0 ================
# ==============2022-01-24 05:40:00 음봉전환 ================
# ==============2022-01-24 05:40:00 이전 5분봉 크기 : 15000.0 ============
# ==================== 구매 tic : 49 ===============
# Buy KRW-BTC, KRW: 9956.7
# ======================== 2022-01-24 05:40:00 시간 매수 완료 : 43290000.0 ===============
# ======================= 양봉전환 stick_size :: -86000.0 ================
# ======================= tic ::::::: 49 =====================
# ============== 수익률 0.01629817591440129 =================
# ======================= 음봉전환 stick_size :: 8000.0 ================
# ==============2022-01-24 05:50:00 음봉전환 ================
# ==============2022-01-24 05:50:00 이전 5분봉 크기 : -7800.0 ============
# ==================== 구매 tic : 49 ===============
# Buy KRW-BTC, KRW: 9973.720000000001
# ======================== 2022-01-24 05:50:00 시간 매수 완료 : 43364000.0 ===============
# ======================= 양봉전환 stick_size :: -39000.0 ================
# ======================= tic ::::::: 49 =====================
# ============== 수익률 0.08106364520969606 =================
# ======================= 음봉전환 stick_size :: 22000.0 ================
# ==============2022-01-24 06:00:00 음봉전환 ================
# ==============2022-01-24 06:00:00 이전 5분봉 크기 : -34800.0 ============
# ==================== 구매 tic : 49 ===============
# Buy KRW-BTC, KRW: 9998.79
# ======================== 2022-01-24 06:00:00 시간 매수 완료 : 43473000.0 ===============
# ======================= 음봉전환 stick_size :: 80000.0 ================
# ==============2022-01-24 06:05:00 음봉전환 ================
# ==============2022-01-24 06:05:00 이전 5분봉 크기 : -15400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 80000.0, 이전5봉 : 15400.0 ==========
# ==================== 구매 tic : 51 ===============
# Buy KRW-BTC, KRW: 9980.39
# ======================== 2022-01-24 06:05:00 시간 매수 완료 : 43393000.0 ===============
# ======================= 음봉전환 stick_size :: 18000.0 ================
# ==============2022-01-24 06:10:00 음봉전환 ================
# ==============2022-01-24 06:10:00 이전 5분봉 크기 : -3000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 18000.0, 이전5봉 : 3000.0 ==========
# ==================== 구매 tic : 53 ===============
# Buy KRW-BTC, KRW: 9976.25
# ======================== 2022-01-24 06:10:00 시간 매수 완료 : 43375000.0 ===============
# ======================= 양봉전환 stick_size :: -95000.0 ================
# ======================= tic ::::::: 53 =====================
# ============== 수익률 0.22893715708657078 =================
# ======================= 양봉전환 stick_size :: -51000.0 ================
# ======================= tic ::::::: 53 =====================
# ============== 수익률 0.3442223390017842 =================
# ======================= 음봉전환 stick_size :: 43000.0 ================
# ==============2022-01-24 06:25:00 음봉전환 ================
# ==============2022-01-24 06:25:00 이전 5분봉 크기 : -5200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 43000.0, 이전5봉 : 5200.0 ==========
# ==================== 구매 tic : 55 ===============
# Buy KRW-BTC, KRW: 10000.17
# ======================== 2022-01-24 06:25:00 시간 매수 완료 : 43479000.0 ===============
# ======================= 음봉전환 stick_size :: 94000.0 ================
# ==============2022-01-24 06:30:00 음봉전환 ================
# ==============2022-01-24 06:30:00 이전 5분봉 크기 : -1000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 94000.0, 이전5봉 : 1000.0 ==========
# ==================== 구매 tic : 57 ===============
# Buy KRW-BTC, KRW: 9978.550000000001
# ======================== 2022-01-24 06:30:00 시간 매수 완료 : 43385000.0 ===============
# ======================= 양봉전환 stick_size :: -23000.0 ================
# ======================= tic ::::::: 57 =====================
# ============== 수익률 0.0803261740670271 =================
# ======================= 양봉전환 stick_size :: -170000.0 ================
# ======================= tic ::::::: 57 =====================
# ============== 수익률 0.4722736365069321 =================
# ======================= 음봉전환 stick_size :: 140000.0 ================
# ==============2022-01-24 06:45:00 음봉전환 ================
# ==============2022-01-24 06:45:00 이전 5분봉 크기 : -21400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 140000.0, 이전5봉 : 21400.0 ==========
# ==================== 구매 tic : 59 ===============
# Buy KRW-BTC, KRW: 9990.74
# ======================== 2022-01-24 06:45:00 시간 매수 완료 : 43438000.0 ===============
# ======================= 음봉전환 stick_size :: 50000.0 ================
# ==============2022-01-24 06:50:00 음봉전환 ================
# ==============2022-01-24 06:50:00 이전 5분봉 크기 : 16800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 50000.0, 이전5봉 : 16800.0 ==========
# ==================== 구매 tic : 61 ===============
# Buy KRW-BTC, KRW: 9987.75
# ======================== 2022-01-24 06:50:00 시간 매수 완료 : 43425000.0 ===============
# ======================= 음봉전환 stick_size :: 55000.0 ================
# ==============2022-01-24 07:00:00 음봉전환 ================
# ==============2022-01-24 07:00:00 이전 5분봉 크기 : -600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 55000.0, 이전5봉 : 600.0 ==========
# ==================== 구매 tic : 63 ===============
# Buy KRW-BTC, KRW: 9975.1
# ======================== 2022-01-24 07:00:00 시간 매수 완료 : 43370000.0 ===============
# ======================= 음봉전환 stick_size :: 26000.0 ================
# ==============2022-01-24 07:10:00 음봉전환 ================
# ==============2022-01-24 07:10:00 이전 5분봉 크기 : 49000.0 ============
# ==================== 구매 tic : 63 ===============
# Buy KRW-BTC, KRW: 9969.12
# ======================== 2022-01-24 07:10:00 시간 매수 완료 : 43344000.0 ===============
# ======================= 양봉전환 stick_size :: -78000.0 ================
# ======================= tic ::::::: 63 =====================
# ============== 수익률 0.11591492740898743 =================
# ======================= 음봉전환 stick_size :: 68000.0 ================
# ==============2022-01-24 07:20:00 음봉전환 ================
# ==============2022-01-24 07:20:00 이전 5분봉 크기 : 600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 68000.0, 이전5봉 : 600.0 ==========
# ==================== 구매 tic : 65 ===============
# ======================= 양봉전환 stick_size :: -41000.0 ================
# ======================= tic ::::::: 65 =====================
# ============== 수익률 0.05597218041733207 =================
# ======================= 음봉전환 stick_size :: 24000.0 ================
# ==============2022-01-24 07:30:00 음봉전환 ================
# ==============2022-01-24 07:30:00 이전 5분봉 크기 : -5000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 24000.0, 이전5봉 : 5000.0 ==========
# ================= 누적 tic_count : 2
# ==================== 구매 tic : 68 ===============
# Buy KRW-BTC, KRW: 9976.25
# ======================== 2022-01-24 07:30:00 시간 매수 완료 : 43375000.0 ===============
# ======================= 음봉전환 stick_size :: 21000.0 ================
# ==============2022-01-24 07:35:00 음봉전환 ================
# ==============2022-01-24 07:35:00 이전 5분봉 크기 : -200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 21000.0, 이전5봉 : 200.0 ==========
# ==================== 구매 tic : 70 ===============
# Buy KRW-BTC, KRW: 9971.42
# ======================== 2022-01-24 07:35:00 시간 매수 완료 : 43354000.0 ===============
# ======================= 음봉전환 stick_size :: 14000.0 ================
# ==============2022-01-24 07:40:00 음봉전환 ================
# ==============2022-01-24 07:40:00 이전 5분봉 크기 : -1200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 14000.0, 이전5봉 : 1200.0 ==========
# ==================== 구매 tic : 72 ===============
# Buy KRW-BTC, KRW: 9968.2
# ======================== 2022-01-24 07:40:00 시간 매수 완료 : 43340000.0 ===============
# ======================= 양봉전환 stick_size :: -91000.0 ================
# ======================= tic ::::::: 72 =====================
# ============== 수익률 0.11584335906901862 =================
# ======================= 양봉전환 stick_size :: -73000.0 ================
# ======================= tic ::::::: 72 =====================
# ============== 수익률 0.2841479041411455 =================
# ======================= 양봉전환 stick_size :: -55000.0 ================
# ======================= tic ::::::: 72 =====================
# ============== 수익률 0.39481390638035224 =================
# ======================= 양봉전환 stick_size :: -213000.0 ================
# ======================= tic ::::::: 72 =====================
# ============== 수익률 0.8858942913168321 =================
# Sell KRW-BTC, Ticker: 0.0
# ======================== 2022-01-24 08:00:00 시간 매도 완료 : 43758000.0 ===============
# ======================= 양봉전환 stick_size :: -66000.0 ================
# ======================= tic ::::::: 0 =====================
# ============== 수익률 0.9873381267027717 =================
# ======================= 양봉전환 stick_size :: -612000.0 ================
# ======================= tic ::::::: 0 =====================
# ============== 수익률 2.405246280392608 =================
# ======================= 음봉전환 stick_size :: 107000.0 ================
# ==============2022-01-24 08:15:00 음봉전환 ================
# ==============2022-01-24 08:15:00 이전 5분봉 크기 : -203800.0 ============
# ======================= 양봉전환 stick_size :: -36000.0 ================
# ======================= tic ::::::: 0 =====================
# ============== 수익률 2.2968858198667177 =================
# ======================= 음봉전환 stick_size :: 75000.0 ================
# ==============2022-01-24 08:25:00 음봉전환 ================
# ==============2022-01-24 08:25:00 이전 5분봉 크기 : -164000.0 ============
# ======================= 음봉전환 stick_size :: 126000.0 ================
# ==============2022-01-24 08:30:00 음봉전환 ================
# ==============2022-01-24 08:30:00 이전 5분봉 크기 : -106400.0 ============
# ================= 누적 tic_count : 2
# ======================= 양봉전환 stick_size :: -96000.0 ================
# ======================= tic ::::::: 1 =====================
# ============== tic값 1 이상 3 미만인경우 ========== 1
# ============== 수익률 1.9510545628691967 =================
# ======================= 음봉전환 stick_size :: 33000.0 ================
# ==============2022-01-24 08:40:00 음봉전환 ================
# ==============2022-01-24 08:40:00 이전 5분봉 크기 : 35200.0 ============
# ======================= 양봉전환 stick_size :: -53000.0 ================
# ======================= tic ::::::: 0 =====================
# ============== 수익률 2.043276231401869 =================
# ======================= 양봉전환 stick_size :: -14000.0 ================
# ======================= tic ::::::: 0 =====================
# ============== 수익률 2.0755538153883046 =================
# ======================= 음봉전환 stick_size :: 21000.0 ================
# ==============2022-01-24 08:55:00 음봉전환 ================
# ==============2022-01-24 08:55:00 이전 5분봉 크기 : -800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 21000.0, 이전5봉 : 800.0 ==========
# ======================= 음봉전환 stick_size :: 119000.0 ================
# ==============2022-01-24 09:00:00 음봉전환 ================
# ==============2022-01-24 09:00:00 이전 5분봉 크기 : -21800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 119000.0, 이전5봉 : 21800.0 ==========
# ================= 누적 tic_count : 2
# ==================== 구매 tic : 5 ===============
# Buy KRW-BTC, KRW: 10151.28
# ======================== 2022-01-24 09:00:00 시간 매수 완료 : 44136000.0 ===============
# ======================= 음봉전환 stick_size :: 42000.0 ================
# ==============2022-01-24 09:05:00 음봉전환 ================
# ==============2022-01-24 09:05:00 이전 5분봉 크기 : 21200.0 ============
# ==================== 구매 tic : 5 ===============
# Buy KRW-BTC, KRW: 10138.630000000001
# ======================== 2022-01-24 09:05:00 시간 매수 완료 : 44081000.0 ===============
# ======================= 음봉전환 stick_size :: 40000.0 ================
# ==============2022-01-24 09:10:00 음봉전환 ================
# ==============2022-01-24 09:10:00 이전 5분봉 크기 : 23000.0 ============
# ==================== 구매 tic : 5 ===============
# Buy KRW-BTC, KRW: 10129.43
# ======================== 2022-01-24 09:10:00 시간 매수 완료 : 44041000.0 ===============
# ======================= 음봉전환 stick_size :: 36000.0 ================
# ==============2022-01-24 09:15:00 음봉전환 ================
# ==============2022-01-24 09:15:00 이전 5분봉 크기 : 41600.0 ============
# ==================== 구매 tic : 5 ===============
# Buy KRW-BTC, KRW: 10121.15
# ======================== 2022-01-24 09:15:00 시간 매수 완료 : 44005000.0 ===============
# ======================= 음봉전환 stick_size :: 189000.0 ================
# ==============2022-01-24 09:20:00 음봉전환 ================
# ==============2022-01-24 09:20:00 이전 5분봉 크기 : 51600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 189000.0, 이전5봉 : 51600.0 ==========
# ==================== 구매 tic : 7 ===============
# Buy KRW-BTC, KRW: 10076.99
# ======================== 2022-01-24 09:20:00 시간 매수 완료 : 43813000.0 ===============
# ======================= 양봉전환 stick_size :: -26000.0 ================
# ======================= tic ::::::: 7 =====================
# ============== 수익률 -0.4003162543848489 =================
# ======================= 양봉전환 stick_size :: -61000.0 ================
# ======================= tic ::::::: 7 =====================
# ============== 수익률 -0.26172776677147896 =================
# ======================= 음봉전환 stick_size :: 14000.0 ================
# ==============2022-01-24 09:35:00 음봉전환 ================
# ==============2022-01-24 09:35:00 이전 5분봉 크기 : 35600.0 ============
# ==================== 구매 tic : 7 ===============
# Buy KRW-BTC, KRW: 10091.25
# ======================== 2022-01-24 09:35:00 시간 매수 완료 : 43875000.0 ===============
# ======================= 양봉전환 stick_size :: -29000.0 ================
# ======================= tic ::::::: 7 =====================
# ============== 수익률 -0.20420456827214706 =================
# ======================= 양봉전환 stick_size :: -88000.0 ================
# ======================= tic ::::::: 7 =====================
# ============== 수익률 -0.0564498713776477 =================
# ======================= 양봉전환 stick_size :: -64000.0 ================
# ======================= tic ::::::: 7 =====================
# ============== 수익률 0.08903167633385935 =================
# ======================= 음봉전환 stick_size :: 142000.0 ================
# ==============2022-01-24 09:55:00 음봉전환 ================
# ==============2022-01-24 09:55:00 이전 5분봉 크기 : -45600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 142000.0, 이전5봉 : 45600.0 ==========
# ==================== 구매 tic : 9 ===============
# Buy KRW-BTC, KRW: 10094.470000000001
# ======================== 2022-01-24 09:55:00 시간 매수 완료 : 43889000.0 ===============
# ======================= 양봉전환 stick_size :: -111000.0 ================
# ======================= tic ::::::: 9 =====================
# ============== 수익률 0.051975051975032605 =================
# ======================= 양봉전환 stick_size :: -65000.0 ================
# ======================= tic ::::::: 9 =====================
# ============== 수익률 0.1997791060290866 =================
# ======================= 음봉전환 stick_size :: 72000.0 ================
# ==============2022-01-24 10:10:00 음봉전환 ================
# ==============2022-01-24 10:10:00 이전 5분봉 크기 : -37200.0 ============
# ==================== 구매 tic : 9 ===============
# Buy KRW-BTC, KRW: 10118.39
# ======================== 2022-01-24 10:10:00 시간 매수 완료 : 43993000.0 ===============
# ======================= 양봉전환 stick_size :: -108000.0 ================
# ======================= tic ::::::: 9 =====================
# ============== 수익률 0.2771201109617177 =================
# ======================= 음봉전환 stick_size :: 107000.0 ================
# ==============2022-01-24 10:20:00 음봉전환 ================
# ==============2022-01-24 10:20:00 이전 5분봉 크기 : -14000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 107000.0, 이전5봉 : 14000.0 ==========
# ==================== 구매 tic : 11 ===============
# Buy KRW-BTC, KRW: 10118.39
# ======================== 2022-01-24 10:20:00 시간 매수 완료 : 43993000.0 ===============
# ======================= 음봉전환 stick_size :: 66000.0 ================
# ==============2022-01-24 10:25:00 음봉전환 ================
# ==============2022-01-24 10:25:00 이전 5분봉 크기 : -21000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 66000.0, 이전5봉 : 21000.0 ==========
# ==================== 구매 tic : 13 ===============
# Buy KRW-BTC, KRW: 10103.44
# ======================== 2022-01-24 10:25:00 시간 매수 완료 : 43928000.0 ===============
# ======================= 음봉전환 stick_size :: 83000.0 ================
# ==============2022-01-24 10:30:00 음봉전환 ================
# ==============2022-01-24 10:30:00 이전 5분봉 크기 : 14400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 83000.0, 이전5봉 : 14400.0 ==========
# ==================== 구매 tic : 15 ===============
# Buy KRW-BTC, KRW: 10077.45
# ======================== 2022-01-24 10:30:00 시간 매수 완료 : 43815000.0 ===============
# ======================= 음봉전환 stick_size :: 21000.0 ================
# ==============2022-01-24 10:35:00 음봉전환 ================
# ==============2022-01-24 10:35:00 이전 5분봉 크기 : 44000.0 ============
# ==================== 구매 tic : 15 ===============
# Buy KRW-BTC, KRW: 10071.470000000001
# ======================== 2022-01-24 10:35:00 시간 매수 완료 : 43789000.0 ===============
# ======================= 음봉전환 stick_size :: 88000.0 ================
# ==============2022-01-24 10:40:00 음봉전환 ================
# ==============2022-01-24 10:40:00 이전 5분봉 크기 : 33800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 88000.0, 이전5봉 : 33800.0 ==========
# ==================== 구매 tic : 17 ===============
# Buy KRW-BTC, KRW: 10051.23
# ======================== 2022-01-24 10:40:00 시간 매수 완료 : 43701000.0 ===============
# ======================= 양봉전환 stick_size :: -63000.0 ================
# ======================= tic ::::::: 17 =====================
# ============== 수익률 -0.3701894200073716 =================
# ======================= 음봉전환 stick_size :: 50000.0 ================
# ==============2022-01-24 10:50:00 음봉전환 ================
# ==============2022-01-24 10:50:00 이전 5분봉 크기 : 39000.0 ============
# ==================== 구매 tic : 17 ===============
# Buy KRW-BTC, KRW: 10054.45
# ======================== 2022-01-24 10:50:00 시간 매수 완료 : 43715000.0 ===============
# ======================= 음봉전환 stick_size :: 3000.0 ================
# ==============2022-01-24 10:55:00 음봉전환 ================
# ==============2022-01-24 10:55:00 이전 5분봉 크기 : 35800.0 ============
# ==================== 구매 tic : 17 ===============
# Buy KRW-BTC, KRW: 10053.76
# ======================== 2022-01-24 10:55:00 시간 매수 완료 : 43712000.0 ===============
# ======================= 음봉전환 stick_size :: 19000.0 ================
# ==============2022-01-24 11:00:00 음봉전환 ================
# ==============2022-01-24 11:00:00 이전 5분봉 크기 : 19800.0 ============
# ==================== 구매 tic : 17 ===============
# Buy KRW-BTC, KRW: 10049.16
# ======================== 2022-01-24 11:00:00 시간 매수 완료 : 43692000.0 ===============
# ======================= 음봉전환 stick_size :: 112000.0 ================
# ==============2022-01-24 11:05:00 음봉전환 ================
# ==============2022-01-24 11:05:00 이전 5분봉 크기 : 19400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 112000.0, 이전5봉 : 19400.0 ==========
# ==================== 구매 tic : 19 ===============
# Buy KRW-BTC, KRW: 10025.01
# ======================== 2022-01-24 11:05:00 시간 매수 완료 : 43587000.0 ===============
# ======================= 음봉전환 stick_size :: 2000.0 ================
# ==============2022-01-24 11:10:00 음봉전환 ================
# ==============2022-01-24 11:10:00 이전 5분봉 크기 : 24200.0 ============
# ==================== 구매 tic : 19 ===============
# Buy KRW-BTC, KRW: 10024.550000000001
# ======================== 2022-01-24 11:10:00 시간 매수 완료 : 43585000.0 ===============
# ======================= 음봉전환 stick_size :: 60000.0 ================
# ==============2022-01-24 11:15:00 음봉전환 ================
# ==============2022-01-24 11:15:00 이전 5분봉 크기 : 37200.0 ============
# ==================== 구매 tic : 19 ===============
# Buy KRW-BTC, KRW: 10010.29
# ======================== 2022-01-24 11:15:00 시간 매수 완료 : 43523000.0 ===============
# ======================= 음봉전환 stick_size :: 20000.0 ================
# ==============2022-01-24 11:20:00 음봉전환 ================
# ==============2022-01-24 11:20:00 이전 5분봉 크기 : 39200.0 ============
# ==================== 구매 tic : 19 ===============
# ======================= 양봉전환 stick_size :: -64000.0 ================
# ======================= tic ::::::: 19 =====================
# ============== 수익률 -0.600931954811822 =================
# ======================= 음봉전환 stick_size :: 52000.0 ================
# ==============2022-01-24 11:30:00 음봉전환 ================
# ==============2022-01-24 11:30:00 이전 5분봉 크기 : 26000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 52000.0, 이전5봉 : 26000.0 ==========
# ================= 누적 tic_count : 2
# ==================== 구매 tic : 22 ===============
# Buy KRW-BTC, KRW: 10009.6
# ======================== 2022-01-24 11:30:00 시간 매수 완료 : 43520000.0 ===============
# ======================= 음봉전환 stick_size :: 109000.0 ================
# ==============2022-01-24 11:35:00 음봉전환 ================
# ==============2022-01-24 11:35:00 이전 5분봉 크기 : 14000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 109000.0, 이전5봉 : 14000.0 ==========
# ==================== 구매 tic : 24 ===============
# Buy KRW-BTC, KRW: 9984.76
# ======================== 2022-01-24 11:35:00 시간 매수 완료 : 43412000.0 ===============
# ======================= 음봉전환 stick_size :: 148000.0 ================
# ==============2022-01-24 11:40:00 음봉전환 ================
# ==============2022-01-24 11:40:00 이전 5분봉 크기 : 35400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 148000.0, 이전5봉 : 35400.0 ==========
# ==================== 구매 tic : 26 ===============
# Buy KRW-BTC, KRW: 9952.79
# ======================== 2022-01-24 11:40:00 시간 매수 완료 : 43273000.0 ===============
# ======================= 음봉전환 stick_size :: 20000.0 ================
# ==============2022-01-24 11:45:00 음봉전환 ================
# ==============2022-01-24 11:45:00 이전 5분봉 크기 : 53000.0 ============
# ==================== 구매 tic : 26 ===============
# Buy KRW-BTC, KRW: 9948.65
# ======================== 2022-01-24 11:45:00 시간 매수 완료 : 43255000.0 ===============
# ======================= 음봉전환 stick_size :: 153000.0 ================
# ==============2022-01-24 11:50:00 음봉전환 ================
# ==============2022-01-24 11:50:00 이전 5분봉 크기 : 53000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 153000.0, 이전5봉 : 53000.0 ==========
# ==================== 구매 tic : 28 ===============
# Buy KRW-BTC, KRW: 9913.460000000001
# ...
# ============== 수익률 -10.90231990399664 =================
# ======================= 양봉전환 stick_size :: -23000.0 ================
# ======================= tic ::::::: 1113 =====================
# ============== 수익률 -10.85889722177241 =================
# ======================= 음봉전환 stick_size :: 8000.0 ================
# ==============2022-02-23 19:00:00 음봉전환 ================
# ==============2022-02-23 19:00:00 이전 5분봉 크기 : 2600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 8000.0, 이전5봉 : 2600.0 ==========
# ==================== 구매 tic : 1115 ===============
# ======================== 2022-02-23 19:00:00 시간 매수 완료 : 47203000.0 ===============
# ======================= 음봉전환 stick_size :: 70000.0 ================
# ==============2022-02-23 19:05:00 음봉전환 ================
# ==============2022-02-23 19:05:00 이전 5분봉 크기 : 4600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 70000.0, 이전5봉 : 4600.0 ==========
# ==================== 구매 tic : 1117 ===============
# ======================== 2022-02-23 19:05:00 시간 매수 완료 : 47134000.0 ===============
# ======================= 음봉전환 stick_size :: 129000.0 ================
# ==============2022-02-23 19:10:00 음봉전환 ================
# ==============2022-02-23 19:10:00 이전 5분봉 크기 : -15000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 129000.0, 이전5봉 : 15000.0 ==========
# ==================== 구매 tic : 1119 ===============
# ======================== 2022-02-23 19:10:00 시간 매수 완료 : 47031000.0 ===============
# ======================= 양봉전환 stick_size :: -48000.0 ================
# ======================= tic ::::::: 1119 =====================
# ============== 수익률 -11.011820580909914 =================
# ======================= 양봉전환 stick_size :: -49000.0 ================
# ======================= tic ::::::: 1119 =====================
# ============== 수익률 -10.919311388345252 =================
# ======================= 음봉전환 stick_size :: 96000.0 ================
# ==============2022-02-23 19:25:00 음봉전환 ================
# ==============2022-02-23 19:25:00 이전 5분봉 크기 : 22000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 96000.0, 이전5봉 : 22000.0 ==========
# ==================== 구매 tic : 1121 ===============
# ======================== 2022-02-23 19:25:00 시간 매수 완료 : 47115000.0 ===============
# ======================= 양봉전환 stick_size :: -23000.0 ================
# ======================= tic ::::::: 1121 =====================
# ============== 수익률 -11.008044695499112 =================
# ======================= 양봉전환 stick_size :: -51000.0 ================
# ======================= tic ::::::: 1121 =====================
# ============== 수익률 -10.892880190469633 =================
# ======================= 음봉전환 stick_size :: 109000.0 ================
# ==============2022-02-23 19:45:00 음봉전환 ================
# ==============2022-02-23 19:45:00 이전 5분봉 크기 : -5400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 109000.0, 이전5봉 : 5400.0 ==========
# ==================== 구매 tic : 1123 ===============
# ======================== 2022-02-23 19:45:00 시간 매수 완료 : 47098000.0 ===============
# ======================= 음봉전환 stick_size :: 48000.0 ================
# ==============2022-02-23 19:50:00 음봉전환 ================
# ==============2022-02-23 19:50:00 이전 5분봉 크기 : 26200.0 ============
# ==================== 구매 tic : 1123 ===============
# ======================== 2022-02-23 19:50:00 시간 매수 완료 : 47045000.0 ===============
# ======================= 양봉전환 stick_size :: -26000.0 ================
# ======================= tic ::::::: 1123 =====================
# ============== 수익률 -11.125097143233994 =================
# ======================= 양봉전환 stick_size :: -25000.0 ================
# ======================= tic ::::::: 1123 =====================
# ============== 수익률 -11.07789857559896 =================
# ======================= 음봉전환 stick_size :: 9000.0 ================
# ==============2022-02-23 20:05:00 음봉전환 ================
# ==============2022-02-23 20:05:00 이전 5분봉 크기 : 21200.0 ============
# ==================== 구매 tic : 1123 ===============
# ======================== 2022-02-23 20:05:00 시간 매수 완료 : 47091000.0 ===============
# ======================= 음봉전환 stick_size :: 99000.0 ================
# ==============2022-02-23 20:10:00 음봉전환 ================
# ==============2022-02-23 20:10:00 이전 5분봉 크기 : 23000.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 99000.0, 이전5봉 : 23000.0 ==========
# ==================== 구매 tic : 1125 ===============
# ======================== 2022-02-23 20:10:00 시간 매수 완료 : 46992000.0 ===============
# ======================= 양봉전환 stick_size :: -58000.0 ================
# ======================= tic ::::::: 1125 =====================
# ============== 수익률 -11.172295710869024 =================
# ======================= 음봉전환 stick_size :: 42000.0 ================
# ==============2022-02-23 20:20:00 음봉전환 ================
# ==============2022-02-23 20:20:00 이전 5분봉 크기 : -200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 42000.0, 이전5봉 : 200.0 ==========
# ==================== 구매 tic : 1127 ===============
# ======================== 2022-02-23 20:20:00 시간 매수 완료 : 47008000.0 ===============
# ======================= 양봉전환 stick_size :: -91000.0 ================
# ======================= tic ::::::: 1127 =====================
# ============== 수익률 -11.079786518304362 =================
# ======================= 양봉전환 stick_size :: -1000.0 ================
# ======================= tic ::::::: 1127 =====================
# ============== 수익률 -11.07789857559896 =================
# ======================= 양봉전환 stick_size :: -2000.0 ================
# ======================= tic ::::::: 1127 =====================
# ============== 수익률 -11.074122690188158 =================
# ======================= 양봉전환 stick_size :: -97000.0 ================
# ======================= tic ::::::: 1127 =====================
# ============== 수익률 -10.890992247764233 =================
# ======================= 음봉전환 stick_size :: 18000.0 ================
# ==============2022-02-23 20:45:00 음봉전환 ================
# ==============2022-02-23 20:45:00 이전 5분봉 크기 : -29800.0 ============
# ==================== 구매 tic : 1127 ===============
# ======================== 2022-02-23 20:45:00 시간 매수 완료 : 47182000.0 ===============
# ======================= 음봉전환 stick_size :: 106000.0 ================
# ==============2022-02-23 20:50:00 음봉전환 ================
# ==============2022-02-23 20:50:00 이전 5분봉 크기 : -34600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 106000.0, 이전5봉 : 34600.0 ==========
# ==================== 구매 tic : 1129 ===============
# ======================== 2022-02-23 20:50:00 시간 매수 완료 : 47088000.0 ===============
# ======================= 음봉전환 stick_size :: 47000.0 ================
# ==============2022-02-23 20:55:00 음봉전환 ================
# ==============2022-02-23 20:55:00 이전 5분봉 크기 : 4800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 47000.0, 이전5봉 : 4800.0 ==========
# ==================== 구매 tic : 1131 ===============
# ======================= 양봉전환 stick_size :: -30000.0 ================
# ======================= tic ::::::: 1131 =====================
# ============== 수익률 -11.059019148544948 =================
# ======================= 양봉전환 stick_size :: -23000.0 ================
# ======================= tic ::::::: 1131 =====================
# ============== 수익률 -11.015596466320718 =================
# ======================= 음봉전환 stick_size :: 21000.0 ================
# ==============2022-02-23 21:10:00 음봉전환 ================
# ==============2022-02-23 21:10:00 이전 5분봉 크기 : 23600.0 ============
# ================= 누적 tic_count : 2
# ==================== 구매 tic : 1132 ===============
# ======================== 2022-02-23 21:10:00 시간 매수 완료 : 47106000.0 ===============
# ======================= 양봉전환 stick_size :: -43000.0 ================
# ======================= tic ::::::: 1132 =====================
# ============== 수익률 -10.985389383034297 =================
# ======================= 양봉전환 stick_size :: -31000.0 ================
# ======================= tic ::::::: 1132 =====================
# ============== 수익률 -10.94763052892627 =================
# ======================= 음봉전환 stick_size :: 3000.0 ================
# ==============2022-02-23 21:25:00 음봉전환 ================
# ==============2022-02-23 21:25:00 이전 5분봉 크기 : -21200.0 ============
# ==================== 구매 tic : 1132 ===============
# ======================== 2022-02-23 21:25:00 시간 매수 완료 : 47169000.0 ===============
# ======================= 양봉전환 stick_size :: -40000.0 ================
# ======================= tic ::::::: 1132 =====================
# ============== 수익률 -10.870224878004818 =================
# ======================= 양봉전환 stick_size :: -44000.0 ================
# ======================= tic ::::::: 1132 =====================
# ============== 수익률 -10.777715685440155 =================
# ======================= 양봉전환 stick_size :: -33000.0 ================
# ======================= tic ::::::: 1132 =====================
# ============== 수익률 -10.715413576161911 =================
# ======================= 양봉전환 stick_size :: -38000.0 ================
# ======================= tic ::::::: 1132 =====================
# ============== 수익률 -10.64178381065126 =================
# ======================= 양봉전환 stick_size :: -50000.0 ================
# ======================= tic ::::::: 1132 =====================
# ============== 수익률 -10.579481701373018 =================
# ======================= 양봉전환 stick_size :: -58000.0 ================
# ======================= tic ::::::: 1132 =====================
# ============== 수익률 -10.515291649389374 =================
# ======================= 음봉전환 stick_size :: 90000.0 ================
# ==============2022-02-23 22:00:00 음봉전환 ================
# ==============2022-02-23 22:00:00 이전 5분봉 크기 : -44600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 90000.0, 이전5봉 : 44600.0 ==========
# ==================== 구매 tic : 1134 ===============
# ======================== 2022-02-23 22:00:00 시간 매수 완료 : 47280000.0 ===============
# ======================= 양봉전환 stick_size :: -57000.0 ================
# ======================= tic ::::::: 1134 =====================
# ============== 수익률 -10.630456154418853 =================
# ======================= 양봉전환 stick_size :: -63000.0 ================
# ======================= tic ::::::: 1134 =====================
# ============== 수익률 -10.51151576397857 =================
# ======================= 양봉전환 stick_size :: -69000.0 ================
# ======================= tic ::::::: 1134 =====================
# ============== 수익률 -10.375583889189679 =================
# ======================= 음봉전환 stick_size :: 169000.0 ================
# ==============2022-02-23 22:20:00 음봉전환 ================
# ==============2022-02-23 22:20:00 이전 5분봉 크기 : -31400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 169000.0, 이전5봉 : 31400.0 ==========
# ==================== 구매 tic : 1136 ===============
# ======================== 2022-02-23 22:20:00 시간 매수 완료 : 47303000.0 ===============
# ======================= 음봉전환 stick_size :: 24000.0 ================
# ==============2022-02-23 22:25:00 음봉전환 ================
# ==============2022-02-23 22:25:00 이전 5분봉 크기 : 14000.0 ============
# ==================== 구매 tic : 1136 ===============
# ======================== 2022-02-23 22:25:00 시간 매수 완료 : 47279000.0 ===============
# ======================= 음봉전환 stick_size :: 45000.0 ================
# ==============2022-02-23 22:30:00 음봉전환 ================
# ==============2022-02-23 22:30:00 이전 5분봉 크기 : 800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 45000.0, 이전5봉 : 800.0 ==========
# ==================== 구매 tic : 1138 ===============
# ======================== 2022-02-23 22:30:00 시간 매수 완료 : 47231000.0 ===============
# ======================= 음봉전환 stick_size :: 46000.0 ================
# ==============2022-02-23 22:35:00 음봉전환 ================
# ==============2022-02-23 22:35:00 이전 5분봉 크기 : 21200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 46000.0, 이전5봉 : 21200.0 ==========
# ==================== 구매 tic : 1140 ===============
# ======================== 2022-02-23 22:35:00 시간 매수 완료 : 47186000.0 ===============
# ======================= 양봉전환 stick_size :: -13000.0 ================
# ======================= tic ::::::: 1140 =====================
# ============== 수익률 -10.890992247764233 =================
# ======================= 양봉전환 stick_size :: -1000.0 ================
# ======================= tic ::::::: 1140 =====================
# ============== 수익률 -10.890992247764233 =================
# ======================= 음봉전환 stick_size :: 53000.0 ================
# ==============2022-02-23 22:50:00 음봉전환 ================
# ==============2022-02-23 22:50:00 이전 5분봉 크기 : 20200.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 53000.0, 이전5봉 : 20200.0 ==========
# ==================== 구매 tic : 1142 ===============
# ======================== 2022-02-23 22:50:00 시간 매수 완료 : 47145000.0 ===============
# ======================= 양봉전환 stick_size :: -68000.0 ================
# ======================= tic ::::::: 1142 =====================
# ============== 수익률 -10.864561049888614 =================
# ======================= 양봉전환 stick_size :: -13000.0 ================
# ======================= tic ::::::: 1142 =====================
# ============== 수익률 -10.840017794718397 =================
# ======================= 음봉전환 stick_size :: 128000.0 ================
# ==============2022-02-23 23:05:00 음봉전환 ================
# ==============2022-02-23 23:05:00 이전 5분봉 크기 : -8400.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 128000.0, 이전5봉 : 8400.0 ==========
# ==================== 구매 tic : 1144 ===============
# ======================== 2022-02-23 23:05:00 시간 매수 완료 : 47098000.0 ===============
# ======================= 음봉전환 stick_size :: 103000.0 ================
# ==============2022-02-23 23:10:00 음봉전환 ================
# ==============2022-02-23 23:10:00 이전 5분봉 크기 : 19800.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 103000.0, 이전5봉 : 19800.0 ==========
# ==================== 구매 tic : 1146 ===============
# ======================== 2022-02-23 23:10:00 시간 매수 완료 : 46997000.0 ===============
# ======================= 양봉전환 stick_size :: -81000.0 ================
# ======================= tic ::::::: 1146 =====================
# ============== 수익률 -11.119433315117789 =================
# ======================= 양봉전환 stick_size :: -45000.0 ================
# ======================= tic ::::::: 1146 =====================
# ============== 수익률 -11.034475893374731 =================
# ======================= 음봉전환 stick_size :: 16000.0 ================
# ==============2022-02-23 23:25:00 음봉전환 ================
# ==============2022-02-23 23:25:00 이전 5분봉 크기 : 18400.0 ============
# ==================== 구매 tic : 1146 ===============
# ======================== 2022-02-23 23:25:00 시간 매수 완료 : 47105000.0 ===============
# ======================= 양봉전환 stick_size :: -107000.0 ================
# ======================= tic ::::::: 1146 =====================
# ============== 수익률 -10.866448992594014 =================
# ======================= 양봉전환 stick_size :: -35000.0 ================
# ======================= tic ::::::: 1146 =====================
# ============== 수익률 -10.875888706121021 =================
# ======================= 음봉전환 stick_size :: 87000.0 ================
# ==============2022-02-23 23:40:00 음봉전환 ================
# ==============2022-02-23 23:40:00 이전 5분봉 크기 : -50400.0 ============
# ==================== 구매 tic : 1146 ===============
# ======================== 2022-02-23 23:40:00 시간 매수 완료 : 47120000.0 ===============
# ======================= 음봉전환 stick_size :: 1000.0 ================
# ==============2022-02-23 23:45:00 음봉전환 ================
# ==============2022-02-23 23:45:00 이전 5분봉 크기 : -16800.0 ============
# ==================== 구매 tic : 1146 ===============
# ======================== 2022-02-23 23:45:00 시간 매수 완료 : 47083000.0 ===============
# ======================= 음봉전환 stick_size :: 177000.0 ================
# ==============2022-02-23 23:50:00 음봉전환 ================
# ==============2022-02-23 23:50:00 이전 5분봉 크기 : -7600.0 ============
# ============= 이전 5봉 평균보다 크다 현재 봉 : 177000.0, 이전5봉 : 7600.0 ==========
# ==================== 구매 tic : 1148 ===============
# ======================== 2022-02-23 23:50:00 시간 매수 완료 : 46906000.0 ===============
# -1.750288734001678 % !!!!!
# -1.750288734001678

# %%
# 0.1 => 0.03 %
# 0.05 => 0.019 %
# 한달 0.05 => -5.4
# 한달 0.1 => -4.11
# 한달 0.5 => -1.75
